# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import time
import re

print("ステップ1: GitHubからデータを取得")

# より詳細なヘッダーを設定（ブラウザのように見せる）
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'ja,en-US;q=0.9,en;q=0.8',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Cache-Control': 'max-age=0'
}

# セッションを使用（Cookieなどを保持）
session = requests.Session()
session.headers.update(headers)

# 重複を避けるために辞書で管理
repositories_dict = {}

# Google組織のリポジトリ一覧ページ
base_url = "https://github.com/orgs/google/repositories"
page = 1
max_pages = 94

print(f"ページを開いています: {base_url}\n")

while page <= max_pages:
    # URLを構築
    if page == 1:
        url = f"{base_url}?tab=repositories"
    else:
        url = f"{base_url}?page={page}&tab=repositories"

    try:
        # ページにアクセス
        res = session.get(url, timeout=15)

        # 503エラーの場合はリトライ
        if res.status_code == 503:
            print(f"  503エラー: 待機後に再試行...")
            time.sleep(5)
            res = session.get(url, timeout=15)

        if res.status_code != 200:
            print(f"[ページ {page}] アクセス失敗 (ステータスコード: {res.status_code})")
            break

        res.encoding = 'utf-8'
        soup = BeautifulSoup(res.content, 'html.parser')

        # リポジトリのリスト項目を取得（複数の方法を試す）
        repo_items = soup.find_all('li', class_='ListItem-module__listItem--k4eMk')

        # 別のクラス名も試す
        if not repo_items:
            repo_items = soup.find_all('li', {'data-testid': lambda x: x and 'repository' in str(x).lower()})

        if not repo_items:
            # より広範囲に検索
            repo_items = soup.find_all('li')
            # リポジトリ名を含むものだけフィルタ
            repo_items = [item for item in repo_items if item.find('a', href=lambda x: x and '/google/' in str(x))]

        if not repo_items:
            print(f"[ページ {page}] リポジトリが見つかりません。全ページ読み込み完了\n")
            break

        print(f"Page {page}:")

        page_count = 0
        for item in repo_items:
            # === リポジトリ名を取得 ===
            repo_name = None

            # 方法1: h4タグ内のa
            title_h4 = item.find('h4', class_='Title-module__heading--s7YnL')
            if title_h4:
                repo_link = title_h4.find('a', class_='Title-module__anchor--GmXUE')
                if repo_link:
                    repo_name = repo_link.get_text().strip()

            # 方法2: itemprop="name codeRepository"
            if not repo_name:
                repo_link = item.find('a', {'itemprop': 'name codeRepository'})
                if repo_link:
                    repo_name = repo_link.get_text().strip()

            # 方法3: href="/google/..."のパターン
            if not repo_name:
                repo_link = item.find('a', href=lambda x: x and x.startswith('/google/'))
                if repo_link:
                    repo_name = repo_link.get_text().strip()

            if not repo_name:
                continue

            # 重複チェック
            if repo_name in repositories_dict:
                continue

            # === 主要な言語を取得 ===
            language = "不明"

            # 方法1: ReposListItem-module__Text_4--mkG7R クラス
            language_span = item.find('span', class_='ReposListItem-module__Text_4--mkG7R')
            if language_span:
                language = language_span.get_text().strip()

            # 方法2: itemprop="programmingLanguage"
            if language == "不明":
                language_span = item.find('span', {'itemprop': 'programmingLanguage'})
                if language_span:
                    language = language_span.get_text().strip()

            # 方法3: LanguageCircle の隣のspan
            if language == "不明":
                lang_circle = item.find('div', class_=lambda x: x and 'LanguageCircle' in str(x))
                if lang_circle and lang_circle.parent:
                    next_span = lang_circle.find_next_sibling('span')
                    if next_span:
                        language = next_span.get_text().strip()

            # 方法4: data-testid="repository-lang-stats-graph"
            if language == "不明":
                lang_div = item.find('div', {'data-testid': 'repository-lang-stats-graph'})
                if lang_div and lang_div.parent:
                    lang_span = lang_div.parent.find('span')
                    if lang_span:
                        language = lang_span.get_text().strip()

            # === スターの数を取得 ===
            stars = 0

            # 方法1: aria-labelに"star"を含むaタグ
            star_link = item.find('a', {'aria-label': lambda x: x and 'star' in str(x).lower()})
            if star_link:
                aria_label = star_link.get('aria-label', '')
                # "34 stars" や "1,234 stars" や "2.5k stars" から数字を抽出
                match = re.search(r'([\d,]+\.?\d*)\s*([km]?)\s*star', aria_label.lower())
                if match:
                    star_text = match.group(1).replace(',', '')
                    unit = match.group(2)
                    if unit == 'k':
                        stars = int(float(star_text) * 1000)
                    elif unit == 'm':
                        stars = int(float(star_text) * 1000000)
                    else:
                        try:
                            stars = int(float(star_text))
                        except:
                            stars = 0

            # 方法2: stargazers へのリンクを探す
            if stars == 0:
                star_link = item.find('a', href=lambda x: x and 'stargazers' in str(x))
                if star_link:
                    # リンクのテキストから数字を取得
                    star_text = star_link.get_text().strip().replace(',', '')
                    if star_text:
                        match = re.search(r'([\d,]+\.?\d*)\s*([km]?)', star_text.lower())
                        if match:
                            num = match.group(1)
                            unit = match.group(2) if len(match.groups()) > 1 else ''
                            if unit == 'k':
                                stars = int(float(num) * 1000)
                            elif unit == 'm':
                                stars = int(float(num) * 1000000)
                            else:
                                try:
                                    stars = int(float(num))
                                except:
                                    stars = 0

            # 方法3: octicon-star アイコンの隣のテキスト
            if stars == 0:
                star_svg = item.find('svg', class_='octicon-star')
                if star_svg and star_svg.parent:
                    # 親要素のテキストからアイコン以外の部分を取得
                    star_text = star_svg.parent.get_text().strip()
                    # 数字だけ抽出
                    match = re.search(r'([\d,]+\.?\d*)\s*([km]?)', star_text.lower())
                    if match:
                        num = match.group(1).replace(',', '')
                        unit = match.group(2) if len(match.groups()) > 1 else ''
                        if unit == 'k':
                            stars = int(float(num) * 1000)
                        elif unit == 'm':
                            stars = int(float(num) * 1000000)
                        else:
                            try:
                                stars = int(float(num))
                            except:
                                stars = 0

            # 重複チェックして辞書に追加
            if repo_name not in repositories_dict:
                repositories_dict[repo_name] = (repo_name, language, stars)
                page_count += 1

                # 指定された形式で表示
                print(f"{page_count}. {repo_name}")
                print(f"    言語: {language}")
                print(f"    スター: {stars}")
                print()

        if page_count == 0:
            print(f"  このページでは新しいリポジトリが見つかりませんでした\n")
        else:
            print(f"ページ {page} 完了: {page_count}件取得 (累計: {len(repositories_dict)}件)")

        print("-" * 70)
        print()

        # 次のページへ
        page += 1

        # 【重要】各リクエストの間に必ず1秒待機
        time.sleep(1)

    except requests.exceptions.Timeout:
        print(f"[ページ {page}] タイムアウトエラー")
        page += 1
        time.sleep(1)
        continue
    except Exception as e:
        print(f"[ページ {page}] エラーが発生: {e}")
        page += 1
        time.sleep(1)
        continue

# 辞書からリストに変換
repositories = list(repositories_dict.values())
print(f"取得完了。 {len(repositories)} 個のリポジトリを取得しました")
print(f"総ページ数: {page - 1}")
# Out:
# ステップ1: GitHubからデータを取得
# ページを開いています: https://github.com/orgs/google/repositories
#
# Page 1:
# 1. device-infra
#     言語: Java
#     スター: 58
#
# 2. nsjail
#     言語: C++
#     スター: 3600
#
# 3. XNNPACK
#     言語: C
#     スター: 2200
#
# 4. skia
#     言語: C++
#     スター: 10000
#
# 5. budoux-extension
#     言語: TypeScript
#     スター: 16
#
# 6. nearby
#     言語: C++
#     スター: 887
#
# 7. qwix
#     言語: Python
#     スター: 64
#
# 8. aarch64-rt
#     言語: Rust
#     スター: 17
#
# 9. percore
#     言語: Rust
#     スター: 8
#
# 10. wuffs
#     言語: C
#     スター: 4700
#
# 11. magika
#     言語: Python
#     スター: 9800
#
# 12. jimfs
#     言語: Java
#     スター: 2500
#
# 13. zerocopy
#     言語: Rust
#     スター: 2100
#
# 14. skia-buildbot
#     言語: Go
#     スター: 158
#
# 15. gtm-session-fetcher
#     言語: Objective-C
#     スター: 265
#
# 16. google-toolbox-for-mac
#     言語: Objective-C
#     スター: 1200
#
# 17. ground-android
#     言語: Kotlin
#     スター: 272
#
# 18. command-fds
#     言語: Rust
#     スター: 42
#
# 19. yapf
#     言語: Python
#     スター: 14000
#
# 20. angle
#     言語: C++
#     スター: 3800
#
# 21. tsl
#     言語: C++
#     スター: 101
#
# 22. osv-scalibr
#     言語: Go
#     スター: 537
#
# 23. synopsys-dw-uart
#     言語: Rust
#     スター: 1
#
# 24. cameratrapai
#     言語: Python
#     スター: 387
#
# 25. double-conversion
#     言語: C++
#     スター: 1200
#
# 26. capslock
#     言語: Go
#     スター: 1100
#
# 27. dive
#     言語: C++
#     スター: 17
#
# 28. tunix
#     言語: Python
#     スター: 1900
#
# 29. adk-samples
#     言語: Python
#     スター: 6400
#
# 30. sedpack
#     言語: Python
#     スター: 28
#
# ページ 1 完了: 30件取得 (累計: 30件)
# ----------------------------------------------------------------------
#
# Page 2:
# 1. go-containerregistry
#     言語: Go
#     スター: 3600
#
# 2. bazel-common
#     言語: Starlark
#     スター: 91
#
# 3. open-dice
#     言語: C++
#     スター: 26
#
# 4. heir
#     言語: C++
#     スター: 609
#
# 5. chromium-policy-vulnfeed
#     言語: Go
#     スター: 7
#
# 6. site-kit-wp
#     言語: JavaScript
#     スター: 1300
#
# 7. toucan
#     言語: C++
#     スター: 48
#
# 8. xls
#     言語: C++
#     スター: 1400
#
# 9. nomulus
#     言語: Java
#     スター: 1800
#
# 10. oss-fuzz
#     言語: Shell
#     スター: 12000
#
# 11. docsy
#     言語: JavaScript
#     スター: 2900
#
# 12. gemma.cpp
#     言語: C++
#     スター: 6600
#
# 13. osv-scanner
#     言語: Go
#     スター: 8100
#
# 14. cassowary.dart
#     言語: Dart
#     スター: 44
#
# 15. flatbuffers
#     言語: C++
#     スター: 25000
#
# 16. dwh-migration-tools
#     言語: Java
#     スター: 54
#
# 17. android-cuttlefish
#     言語: C++
#     スター: 571
#
# 18. ink
#     言語: C++
#     スター: 49
#
# 19. or-tools
#     言語: C++
#     スター: 13000
#
# 20. earthengine-catalog
#     言語: Jsonnet
#     スター: 121
#
# 21. error-prone
#     言語: Java
#     スター: 7100
#
# 22. perfetto
#     言語: C++
#     スター: 5000
#
# 23. oss-fuzz-vulns
#     言語: Python
#     スター: 166
#
# 24. meridian
#     言語: Python
#     スター: 1200
#
# 25. gn-language-server
#     言語: Rust
#     スター: 18
#
# 26. matr
#     言語: Rust
#     スター: 9
#
# 27. dawn
#     言語: C++
#     スター: 778
#
# 28. langfun
#     言語: Python
#     スター: 875
#
# 29. osv-scanner-v1
#     言語: Go
#     スター: 2
#
# 30. adk-docs
#     言語: HTML
#     スター: 975
#
# ページ 2 完了: 30件取得 (累計: 60件)
# ----------------------------------------------------------------------
#
# Page 3:
# 1. quiche
#     言語: C++
#     スター: 801
#
# 2. private-compute-libraries
#     言語: Kotlin
#     スター: 34
#
# 3. gson
#     言語: Java
#     スター: 24000
#
# 4. kafel
#     言語: C
#     スター: 340
#
# 5. adk-python
#     言語: Python
#     スター: 16000
#
# 6. mug
#     言語: Java
#     スター: 444
#
# 7. biva
#     言語: C++
#     スター: 6
#
# 8. gvisor
#     言語: Go
#     スター: 17000
#
# 9. tabuli
#     言語: C++
#     スター: 35
#
# 10. filament
#     言語: C++
#     スター: 19000
#
# 11. adk-go
#     言語: Go
#     スター: 4700
#
# 12. Xee
#     言語: Python
#     スター: 320
#
# 13. safevalues
#     言語: TypeScript
#     スター: 137
#
# 14. init2winit
#     言語: Python
#     スター: 79
#
# 15. jetpack-camera-app
#     言語: Kotlin
#     スター: 276
#
# 16. orbax
#     言語: Python
#     スター: 455
#
# 17. eclipsa-audio-plugin
#     言語: C++
#     スター: 56
#
# 18. adk-js
#     言語: TypeScript
#     スター: 99
#
# 19. crubit
#     言語: C++
#     スター: 924
#
# 20. cel-java
#     言語: Java
#     スター: 227
#
# 21. cel-spec
#     言語: Starlark
#     スター: 3500
#
# 22. crosvm
#     言語: Rust
#     スター: 1100
#
# 23. grain
#     言語: Python
#     スター: 602
#
# 24. ground-platform
#     言語: TypeScript
#     スター: 227
#
# 25. earthengine-api
#     言語: JavaScript
#     スター: 3100
#
# 26. closure-compiler
#     言語: JavaScript
#     スター: 7600
#
# 27. dotprompt
#     言語: Python
#     スター: 329
#
# 28. kotlin-fhirpath
#     言語: Kotlin
#     スター: 6
#
# 29. bloaty
#     言語: C++
#     スター: 5300
#
# 30. civics_cdf_validator
#     言語: Python
#     スター: 34
#
# ページ 3 完了: 30件取得 (累計: 90件)
# ----------------------------------------------------------------------
#
# Page 4:
# 1. netkat
#     言語: C++
#     スター: 27
#
# 2. koladata
#     言語: C++
#     スター: 27
#
# 3. virtual-printer
#     言語: Kotlin
#     スター: 2
#
# 4. garf
#     言語: Python
#     スター: 11
#
# 5. benchmark
#     言語: C++
#     スター: 9900
#
# 6. digitalbuildings
#     言語: Python
#     スター: 424
#
# 7. oracle-toolkit
#     言語: Shell
#     スター: 65
#
# 8. fuzztest
#     言語: C++
#     スター: 924
#
# 9. fonts
#     言語: HTML
#     スター: 19000
#
# 10. gfxstream
#     言語: C++
#     スター: 21
#
# 11. clusterfuzz
#     言語: Python
#     スター: 5500
#
# 12. xrblocks
#     言語: TypeScript
#     スター: 153
#
# 13. cel-cpp
#     言語: C++
#     スター: 205
#
# 14. closure-templates
#     言語: Java
#     スター: 671
#
# 15. TestParameterInjector
#     言語: Java
#     スター: 415
#
# 16. sec-gemini
#     言語: Svelte
#     スター: 107
#
# 17. secure-aggregation
#     言語: Rust
#     スター: 5
#
# 18. security-research
#     言語: C
#     スター: 4300
#
# 19. automotive-design-compose
#     言語: Rust
#     スター: 167
#
# 20. dagger
#     言語: Java
#     スター: 18000
#
# 21. embardiment
#     言語: C#
#     スター: 10
#
# 22. llvm-propeller
#     言語: C++
#     スター: 464
#
# 23. syzkaller
#     言語: Go
#     スター: 5900
#
# 24. adk-java
#     言語: Java
#     スター: 966
#
# 25. ecclesia-machine-management
#     言語: C++
#     スター: 15
#
# 26. zx
#     言語: JavaScript
#     スター: 45000
#
# 27. s2geometry
#     言語: C++
#     スター: 2600
#
# 28. earthengine-community
#     言語: Jupyter Notebook
#     スター: 743
#
# 29. timesketch
#     言語: Python
#     スター: 3200
#
# 30. yggdrasil-decision-forests
#     言語: C++
#     スター: 621
#
# ページ 4 完了: 30件取得 (累計: 120件)
# ----------------------------------------------------------------------
#
# Page 5:
# 1. testrun
#     言語: Python
#     スター: 42
#
# 2. dart-neats
#     言語: Dart
#     スター: 503
#
# 3. mozc
#     言語: C++
#     スター: 2800
#
# 4. highway
#     言語: C++
#     スター: 5100
#
# 5. go-querystring
#     言語: Go
#     スター: 2100
#
# 6. brotli
#     言語: TypeScript
#     スター: 14000
#
# 7. googletest-rust
#     言語: Rust
#     スター: 393
#
# 8. built_value.dart
#     言語: Dart
#     スター: 883
#
# 9. brax
#     言語: Jupyter Notebook
#     スター: 2900
#
# 10. seesaw
#     言語: Go
#     スター: 5700
#
# 11. oboe
#     言語: C++
#     スター: 4000
#
# 12. boringssl
#     言語: C++
#     スター: 2100
#
# 13. torchax
#     言語: Python
#     スター: 130
#
# 14. go-units
#     言語: Go
#     スター: 7
#
# 15. osv.dev
#     言語: Python
#     スター: 2400
#
# 16. j2cl
#     言語: Java
#     スター: 1300
#
# 17. ml-metrics
#     言語: Python
#     スター: 19
#
# 18. pullsheet
#     言語: Go
#     スター: 88
#
# 19. nsscache
#     言語: Python
#     スター: 150
#
# 20. tcmalloc
#     言語: C++
#     スター: 5000
#
# 21. aqt
#     言語: Python
#     スター: 337
#
# 22. pdl
#     言語: Rust
#     スター: 66
#
# 23. mcp-security
#     言語: Python
#     スター: 404
#
# 24. oss-rebuild
#     言語: Go
#     スター: 669
#
# 25. atheris
#     言語: Python
#     スター: 1500
#
# 26. adk-python-community
#     言語: Python
#     スター: 95
#
# 27. json_serializable.dart
#     言語: Dart
#     スター: 1600
#
# 28. ksp
#     言語: Kotlin
#     スター: 3300
#
# 29. jsonschema-go
#     言語: Go
#     スター: 139
#
# 30. gops
#     言語: Go
#     スター: 7000
#
# ページ 5 完了: 30件取得 (累計: 150件)
# ----------------------------------------------------------------------
#
# Page 6:
# 1. tarpc
#     言語: Rust
#     スター: 3600
#
# 2. dranet
#     言語: Go
#     スター: 146
#
# 3. go-attestation
#     言語: Go
#     スター: 404
#
# 4. filonov
#     言語: Python
#     スター: 10
#
# 5. libnss-cache
#     言語: C
#     スター: 61
#
# 6. assertor
#     言語: Rust
#     スター: 144
#
# 7. flax
#     言語: Jupyter Notebook
#     スター: 6900
#
# 8. clspv
#     言語: LLVM
#     スター: 693
#
# 9. langextract
#     言語: Python
#     スター: 17000
#
# 10. pack
#     言語: Rust
#     スター: 202
#
# 11. gurl
#     言語: C++
#     スター: 0
#
# 12. shell-encryption
#     言語: C++
#     スター: 124
#
# 13. certificate-transparency-go
#     言語: Go
#     スター: 1100
#
# 14. source_helper.dart
#     言語: Dart
#     スター: 16
#
# 15. conscrypt
#     言語: Java
#     スター: 1400
#
# 16. libphonenumber
#     言語: C++
#     スター: 18000
#
# 17. copybara
#     言語: Java
#     スター: 2500
#
# 18. sentencepiece
#     言語: C++
#     スター: 11000
#
# 19. snappy
#     言語: C++
#     スター: 6500
#
# 20. trillian-examples
#     言語: Go
#     スター: 173
#
# 21. android-security-lints
#     言語: Kotlin
#     スター: 153
#
# 22. secops-wrapper
#     言語: Python
#     スター: 44
#
# 23. workflow-graph
#     言語: TypeScript
#     スター: 149
#
# 24. android-fhir
#     言語: Kotlin
#     スター: 571
#
# 25. silifuzz
#     言語: C++
#     スター: 412
#
# 26. tensorstore
#     言語: C++
#     スター: 1500
#
# 27. peoplemath
#     言語: TypeScript
#     スター: 128
#
# 28. fscrypt
#     言語: Go
#     スター: 983
#
# 29. trillian
#     言語: Go
#     スター: 3700
#
# 30. go-github
#     言語: Go
#     スター: 11000
#
# ページ 6 完了: 30件取得 (累計: 180件)
# ----------------------------------------------------------------------
#
# Page 7:
# 1. gke-policy-automation
#     言語: Go
#     スター: 525
#
# 2. merchant-api-samples
#     言語: Java
#     スター: 10
#
# 3. go-cloud
#     言語: Go
#     スター: 9800
#
# 4. aoss-verifier
#     言語: Go
#     スター: 25
#
# 5. go-jsonnet
#     言語: Go
#     スター: 1800
#
# 6. certtostore
#     言語: Go
#     スター: 96
#
# 7. neuroglancer
#     言語: TypeScript
#     スター: 1200
#
# 8. minijail
#     言語: C
#     スター: 342
#
# 9. osv-scanner-action
#     言語: Python
#     スター: 47
#
# 10. jax-datetime
#     言語: Python
#     スター: 2
#
# 11. glome
#     言語: C
#     スター: 63
#
# 12. gutil
#     言語: C++
#     スター: 11
#
# 13. fleetbench
#     言語: C++
#     スター: 134
#
# 14. across
#     言語: HTML
#     スター: 21
#
# 15. scaaml
#     言語: Python
#     スター: 175
#
# 16. fhir
#     言語: C++
#     スター: 904
#
# 17. horologist
#     言語: Kotlin
#     スター: 657
#
# 18. nccl-plugin-gpudirect-tcpxo
#     言語: C++
#     スター: 6
#
# 19. gnostic-models
#     言語: Go
#     スター: 20
#
# 20. go-sev-guest
#     言語: Go
#     スター: 66
#
# 21. fhir-gateway
#     言語: Java
#     スター: 90
#
# 22. kotlin
#     言語: Kotlin
#     スター: 153
#
# 23. android-beat
#     言語: 不明
#     スター: 2
#
# 24. bumble
#     言語: Python
#     スター: 426
#
# 25. gwpsan
#     言語: C++
#     スター: 327
#
# 26. nftables
#     言語: Go
#     スター: 1300
#
# 27. wasefire
#     言語: Rust
#     スター: 127
#
# 28. clasp
#     言語: TypeScript
#     スター: 5300
#
# 29. guava
#     言語: Java
#     スター: 51000
#
# 30. go-tdx-guest
#     言語: Go
#     スター: 79
#
# ページ 7 完了: 30件取得 (累計: 210件)
# ----------------------------------------------------------------------
#
# Page 8:
# 1. googleapis.dart
#     言語: Dart
#     スター: 408
#
# 2. openhtf
#     言語: Python
#     スター: 613
#
# 3. github_workflows_playground
#     言語: 不明
#     スター: 8
#
# 4. adk-web
#     言語: TypeScript
#     スター: 675
#
# 5. gce-tcb-verifier
#     言語: Go
#     スター: 22
#
# 6. github-team
#     言語: Shell
#     スター: 2
#
# 7. pyglove
#     言語: Python
#     スター: 699
#
# 8. shaderc
#     言語: C++
#     スター: 2100
#
# 9. fhir-data-pipes
#     言語: Jupyter Notebook
#     スター: 204
#
# 10. cel-go
#     言語: Go
#     スター: 2800
#
# 11. arolla
#     言語: C++
#     スター: 23
#
# 12. inverting-proxy
#     言語: Go
#     スター: 262
#
# 13. ChromeBrowserEnterprise
#     言語: C#
#     スター: 57
#
# 14. travel-impact-model-website
#     言語: TypeScript
#     スター: 5
#
# 15. learned_optimization
#     言語: Python
#     スター: 788
#
# 16. rpmpack
#     言語: Go
#     スター: 128
#
# 17. cctz
#     言語: C++
#     スター: 631
#
# 18. weather-tools
#     言語: Python
#     スター: 241
#
# 19. schema-dts
#     言語: TypeScript
#     スター: 1100
#
# 20. foteli
#     言語: C++
#     スター: 5
#
# 21. protobuf.dart
#     言語: Dart
#     スター: 558
#
# 22. mdbook-i18n-helpers
#     言語: Rust
#     スター: 194
#
# 23. deps.dev
#     言語: Go
#     スター: 354
#
# 24. tsec
#     言語: TypeScript
#     スター: 141
#
# 25. github-sandbox
#     言語: 不明
#     スター: 16
#
# 26. dotguides
#     言語: TypeScript
#     スター: 21
#
# 27. aarch64-esr-decoder
#     言語: Rust
#     スター: 99
#
# 28. torq
#     言語: Python
#     スター: 2
#
# 29. osdfir-infrastructure
#     言語: Smarty
#     スター: 171
#
# 30. github_nonpublic_api
#     言語: Python
#     スター: 43
#
# ページ 8 完了: 30件取得 (累計: 240件)
# ----------------------------------------------------------------------
#
# Page 9:
# 1. libhoth
#     言語: C
#     スター: 17
#
# 2. oss-fuzz-gen
#     言語: Python
#     スター: 1300
#
# 3. auto
#     言語: Java
#     スター: 11000
#
# 4. xctestrunner
#     言語: Python
#     スター: 153
#
# 5. escapevelocity
#     言語: Java
#     スター: 39
#
# 6. postcss-rename
#     言語: TypeScript
#     スター: 162
#
# 7. praxis
#     言語: Python
#     スター: 190
#
# 8. transit
#     言語: 不明
#     スター: 852
#
# 9. riegeli
#     言語: C++
#     スター: 465
#
# 10. swiftshader
#     言語: C++
#     スター: 2400
#
# 11. osdemo
#     言語: Rust
#     スター: 8
#
# 12. j2objc
#     言語: Java
#     スター: 6000
#
# 13. turbine
#     言語: Java
#     スター: 82
#
# 14. differential-privacy
#     言語: Go
#     スター: 3300
#
# 15. caliper
#     言語: Java
#     スター: 819
#
# 16. aidl-language
#     言語: 不明
#     スター: 23
#
# 17. selinux-policy-languages
#     言語: 不明
#     スター: 14
#
# 18. pdl-language
#     言語: 不明
#     スター: 26
#
# 19. comprehensive-rust
#     言語: Rust
#     スター: 32000
#
# 20. webcrypto.dart
#     言語: Dart
#     スター: 97
#
# 21. budoux
#     言語: Python
#     スター: 1500
#
# 22. pytype
#     言語: Python
#     スター: 5000
#
# 23. paxml
#     言語: Python
#     スター: 540
#
# 24. renameio
#     言語: Go
#     スター: 667
#
# 25. seqio
#     言語: Python
#     スター: 589
#
# 26. alioth
#     言語: Rust
#     スター: 307
#
# 27. iwa-vscode-extension
#     言語: TypeScript
#     スター: 3
#
# 28. mobly
#     言語: Python
#     スター: 716
#
# 29. project-voice
#     言語: TypeScript
#     スター: 49
#
# 30. duet
#     言語: Python
#     スター: 24
#
# ページ 9 完了: 30件取得 (累計: 270件)
# ----------------------------------------------------------------------
#
# Page 10:
# 1. cro3
#     言語: Rust
#     スター: 49
#
# 2. arb-editor
#     言語: TypeScript
#     スター: 56
#
# 3. codeql-action
#     言語: TypeScript
#     スター: 0
#
# 4. dfindexeddb
#     言語: Python
#     スター: 38
#
# 5. sound-checker
#     言語: Kotlin
#     スター: 22
#
# 6. traceviz
#     言語: TypeScript
#     スター: 4
#
# 7. etils
#     言語: Python
#     スター: 244
#
# 8. labs-prototypes
#     言語: Jupyter Notebook
#     スター: 85
#
# 9. vector_math.dart
#     言語: Dart
#     スター: 341
#
# 10. pprof
#     言語: Go
#     スター: 8900
#
# 11. rust-crate-audits
#     言語: 不明
#     スター: 255
#
# 12. aside
#     言語: TypeScript
#     スター: 392
#
# 13. privacy-sandbox-aggregation-service
#     言語: Go
#     スター: 28
#
# 14. rbrotli-enc
#     言語: Rust
#     スター: 13
#
# 15. ads-api-report-fetcher
#     言語: TypeScript
#     スター: 53
#
# 16. guice
#     言語: Java
#     スター: 13000
#
# 17. mobly-bundled-snippets
#     言語: Java
#     スター: 54
#
# 18. metrax
#     言語: Python
#     スター: 47
#
# 19. symphony-gcp
#     言語: Python
#     スター: 1
#
# 20. ml-compiler-opt
#     言語: Python
#     スター: 737
#
# 21. google-cloud-datastore-quadruple
#     言語: M4
#     スター: 2
#
# 22. styleguide
#     言語: HTML
#     スター: 39000
#
# 23. array_record
#     言語: C++
#     スター: 123
#
# 24. mobly-android-screen-recorder
#     言語: Python
#     スター: 5
#
# 25. certificate-transparency-community-site
#     言語: HTML
#     スター: 132
#
# 26. tsunami-security-scanner-plugins
#     言語: Java
#     スター: 942
#
# 27. tsunami-security-scanner
#     言語: Java
#     スター: 8500
#
# 28. keep-sorted
#     言語: Go
#     スター: 316
#
# 29. docsy-example
#     言語: HTML
#     スター: 537
#
# 30. perf_data_converter
#     言語: C++
#     スター: 331
#
# ページ 10 完了: 30件取得 (累計: 300件)
# ----------------------------------------------------------------------
#
# Page 11:
# 1. android-emulator-hypervisor-driver
#     言語: C
#     スター: 841
#
# 2. ads_oneshop
#     言語: Python
#     スター: 19
#
# 3. EarlGrey
#     言語: Objective-C
#     スター: 5700
#
# 4. zetasql
#     言語: C++
#     スター: 2400
#
# 5. myvibe
#     言語: 不明
#     スター: 4
#
# 6. business_intelligence_group
#     言語: Jupyter Notebook
#     スター: 14
#
# 7. mobly-bluetooth-ref-validation
#     言語: Python
#     スター: 5
#
# 8. googletest
#     言語: C++
#     スター: 38000
#
# 9. cloud-android-orchestration
#     言語: Go
#     スター: 58
#
# 10. compile-testing
#     言語: Java
#     スター: 715
#
# 11. fhir-py
#     言語: Python
#     スター: 94
#
# 12. product_video_ads
#     言語: TypeScript
#     スター: 61
#
# 13. xplat
#     言語: Java
#     スター: 18
#
# 14. go-tpm
#     言語: Go
#     スター: 616
#
# 15. guava-beta-checker
#     言語: Java
#     スター: 91
#
# 16. google-authenticator-libpam
#     言語: C
#     スター: 1900
#
# 17. spatial-media
#     言語: Python
#     スター: 2000
#
# 18. truth
#     言語: Java
#     スター: 2800
#
# 19. longfellow-zk
#     言語: C++
#     スター: 983
#
# 20. kernel-research
#     言語: C++
#     スター: 48
#
# 21. bindiff
#     言語: Java
#     スター: 2800
#
# 22. shifter
#     言語: Go
#     スター: 45
#
# 23. cddlconv
#     言語: TypeScript
#     スター: 11
#
# 24. coset
#     言語: Rust
#     スター: 38
#
# 25. sbom-conformance
#     言語: Go
#     スター: 2
#
# 26. starlark-go
#     言語: Go
#     スター: 2600
#
# 27. GoogleSignIn-iOS
#     言語: Objective-C
#     スター: 667
#
# 28. rust_icu
#     言語: Rust
#     スター: 128
#
# 29. jsir
#     言語: C++
#     スター: 108
#
# 30. walt
#     言語: Java
#     スター: 462
#
# ページ 11 完了: 30件取得 (累計: 330件)
# ----------------------------------------------------------------------
#
# Page 12:
# 1. meterstick
#     言語: Jupyter Notebook
#     スター: 109
#
# 2. cpu_features
#     言語: C++
#     スター: 2600
#
# 3. binexport
#     言語: C++
#     スター: 1200
#
# 4. kotlin-fhir
#     言語: Kotlin
#     スター: 53
#
# 5. saxml
#     言語: Python
#     スター: 146
#
# 6. ever
#     言語: Jupyter Notebook
#     スター: 14
#
# 7. sso-offloading
#     言語: TypeScript
#     スター: 1
#
# 8. kf
#     言語: Go
#     スター: 400
#
# 9. vizier
#     言語: Python
#     スター: 1600
#
# 10. instrumentsToPprof
#     言語: Go
#     スター: 52
#
# 11. mozc-devices
#     言語: C++
#     スター: 2700
#
# 12. ml_collections
#     言語: Python
#     スター: 998
#
# 13. graph-renderer
#     言語: 不明
#     スター: 0
#
# 14. container-explorer
#     言語: Go
#     スター: 89
#
# 15. googet
#     言語: Go
#     スター: 98
#
# 16. google-api-objectivec-client-for-rest
#     言語: Objective-C
#     スター: 830
#
# 17. desugar_jdk_libs
#     言語: Java
#     スター: 389
#
# 18. uncertainty-baselines
#     言語: Python
#     スター: 1600
#
# 19. bt-navi-tests
#     言語: Python
#     スター: 5
#
# 20. go-tpm-tools
#     言語: C
#     スター: 271
#
# 21. jax-cfd
#     言語: Jupyter Notebook
#     スター: 894
#
# 22. p4-infra
#     言語: C++
#     スター: 1
#
# 23. kotlin_convert
#     言語: Kotlin
#     スター: 20
#
# 24. built_collection.dart
#     言語: Dart
#     スター: 283
#
# 25. quiver-dart
#     言語: Dart
#     スター: 1100
#
# 26. pthreadpool
#     言語: C++
#     スター: 22
#
# 27. webkit_inspection_protocol.dart
#     言語: Dart
#     スター: 33
#
# 28. semantic-locators
#     言語: JavaScript
#     スター: 58
#
# 29. brotli-wheels
#     言語: 不明
#     スター: 10
#
# 30. openintent
#     言語: 不明
#     スター: 33
#
# ページ 12 完了: 30件取得 (累計: 360件)
# ----------------------------------------------------------------------
#
# Page 13:
# 1. re2
#     言語: C++
#     スター: 9500
#
# 2. bughunters
#     言語: 不明
#     スター: 139
#
# 3. filament-assets
#     言語: Mathematica
#     スター: 1
#
# 4. xarray-beam
#     言語: Python
#     スター: 158
#
# 5. gsocguides
#     言語: CSS
#     スター: 475
#
# 6. mpact-cheriot
#     言語: C++
#     スター: 6
#
# 7. glazier
#     言語: Python
#     スター: 1200
#
# 8. mpact-riscv
#     言語: C++
#     スター: 26
#
# 9. tfp-causalimpact
#     言語: Python
#     スター: 135
#
# 10. fscryptctl
#     言語: C
#     スター: 137
#
# 11. capirca
#     言語: Python
#     スター: 839
#
# 12. imt
#     言語: C++
#     スター: 5
#
# 13. neper
#     言語: C
#     スター: 318
#
# 14. autofdo
#     言語: C++
#     スター: 575
#
# 15. ARC-GEN
#     言語: Python
#     スター: 33
#
# 16. fresnel
#     言語: Go
#     スター: 55
#
# 17. dart_cli_pkg
#     言語: Dart
#     スター: 61
#
# 18. fiddle
#     言語: Python
#     スター: 364
#
# 19. elemental2
#     言語: Java
#     スター: 167
#
# 20. jsinterop-base
#     言語: Java
#     スター: 72
#
# 21. jsinterop-annotations
#     言語: Java
#     スター: 21
#
# 22. jsinterop-generator
#     言語: Java
#     スター: 82
#
# 23. genie-for-sap-abap-ai-assistant-sample
#     言語: ABAP
#     スター: 26
#
# 24. omaha-client
#     言語: Rust
#     スター: 6
#
# 25. sbat-rs
#     言語: Rust
#     スター: 18
#
# 26. authenticode-rs
#     言語: Rust
#     スター: 30
#
# 27. gpt-disk-rs
#     言語: Rust
#     スター: 71
#
# 28. hackable_diffusion
#     言語: Python
#     スター: 24
#
# 29. zimtohrli
#     言語: Jupyter Notebook
#     スター: 172
#
# 30. uri.dart
#     言語: Dart
#     スター: 80
#
# ページ 13 完了: 30件取得 (累計: 390件)
# ----------------------------------------------------------------------
#
# Page 14:
# 1. mangle
#     言語: Go
#     スター: 2900
#
# 2. mono_repo.dart
#     言語: Dart
#     スター: 165
#
# 3. python-fire
#     言語: Python
#     スター: 28000
#
# 4. ragvis
#     言語: 不明
#     スター: 1
#
# 5. xarray-tensorstore
#     言語: Python
#     スター: 61
#
# 6. flogger
#     言語: Java
#     スター: 1500
#
# 7. breakpad
#     言語: C++
#     スター: 2800
#
# 8. hotels-template-library
#     言語: C++
#     スター: 24
#
# 9. google-ctf
#     言語: Python
#     スター: 4800
#
# 10. process_runner
#     言語: Dart
#     スター: 20
#
# 11. nsync
#     言語: C
#     スター: 1200
#
# 12. quic-trace
#     言語: C++
#     スター: 119
#
# 13. temporian
#     言語: Python
#     スター: 703
#
# 14. mtail
#     言語: Go
#     スター: 4000
#
# 15. obr
#     言語: C++
#     スター: 22
#
# 16. turbinia
#     言語: Python
#     スター: 777
#
# 17. google-java-format
#     言語: Java
#     スター: 6000
#
# 18. addlicense
#     言語: Go
#     スター: 850
#
# 19. GoogleAppMeasurement
#     言語: Swift
#     スター: 31
#
# 20. rrg
#     言語: Rust
#     スター: 59
#
# 21. evt-air-risk-aiaa-scitech-2026
#     言語: Python
#     スター: 2
#
# 22. watchface
#     言語: Kotlin
#     スター: 52
#
# 23. der-ascii
#     言語: Go
#     スター: 248
#
# 24. inject-common
#     言語: Java
#     スター: 11
#
# 25. jaxite
#     言語: Python
#     スター: 88
#
# 26. airio
#     言語: Python
#     スター: 21
#
# 27. buzzer
#     言語: Go
#     スター: 468
#
# 28. jpegli
#     言語: C++
#     スター: 277
#
# 29. ts-bridge
#     言語: Go
#     スター: 54
#
# 30. slo-generator
#     言語: Python
#     スター: 546
#
# ページ 14 完了: 30件取得 (累計: 420件)
# ----------------------------------------------------------------------
#
# Page 15:
# 1. autobound
#     言語: Python
#     スター: 363
#
# 2. pdsl-xray
#     言語: Java
#     スター: 2
#
# 3. test-server
#     言語: Go
#     スター: 17
#
# 4. sbsim
#     言語: Python
#     スター: 86
#
# 5. tracey
#     言語: Go
#     スター: 6
#
# 6. smbios-validation-tool
#     言語: Go
#     スター: 12
#
# 7. pmax_best_practices_dashboard
#     言語: Shell
#     スター: 52
#
# 8. pubmed-rag
#     言語: Jupyter Notebook
#     スター: 11
#
# 9. loudness_ebur128
#     言語: C++
#     スター: 3
#
# 10. python-proto-converter
#     言語: Python
#     スター: 15
#
# 11. pathways-job
#     言語: Go
#     スター: 15
#
# 12. humanio
#     言語: JavaScript
#     スター: 14
#
# 13. anonymous-tokens
#     言語: C++
#     スター: 58
#
# 14. eDistantObject
#     言語: Objective-C
#     スター: 176
#
# 15. fleetspeak
#     言語: Go
#     スター: 142
#
# 16. yamlfmt
#     言語: Go
#     スター: 1600
#
# 17. tf-shell
#     言語: Python
#     スター: 9
#
# 18. rootcanal
#     言語: C++
#     スター: 30
#
# 19. skcms
#     言語: 不明
#     スター: 3
#
# 20. deepvariant
#     言語: Python
#     スター: 3600
#
# 21. drjax
#     言語: Python
#     スター: 15
#
# 22. jaxloop
#     言語: Jupyter Notebook
#     スター: 18
#
# 23. private-join-and-compute
#     言語: C++
#     スター: 833
#
# 24. gnxi
#     言語: Python
#     スター: 282
#
# 25. winops
#     言語: Go
#     スター: 121
#
# 26. intellij-community
#     言語: Java
#     スター: 12
#
# 27. wireit
#     言語: TypeScript
#     スター: 6300
#
# 28. aarch64-paging
#     言語: Rust
#     スター: 38
#
# 29. OpenSK
#     言語: Rust
#     スター: 3200
#
# 30. capsem
#     言語: Python
#     スター: 0
#
# ページ 15 完了: 30件取得 (累計: 450件)
# ----------------------------------------------------------------------
#
# Page 16:
# 1. private-membership
#     言語: C++
#     スター: 49
#
# 2. rune
#     言語: C
#     スター: 1900
#
# 3. trillian-website
#     言語: HTML
#     スター: 12
#
# 4. vanir
#     言語: Python
#     スター: 342
#
# 5. cabbie
#     言語: Go
#     スター: 99
#
# 6. travel-impact-model
#     言語: 不明
#     スター: 164
#
# 7. sandboxed-api
#     言語: C++
#     スター: 1700
#
# 8. deepsomatic
#     言語: 不明
#     スター: 275
#
# 9. licenseclassifier
#     言語: Go
#     スター: 339
#
# 10. distbench
#     言語: C++
#     スター: 54
#
# 11. ide-perf
#     言語: Kotlin
#     スター: 65
#
# 12. native-pkcs11
#     言語: Rust
#     スター: 64
#
# 13. mpact-sim
#     言語: C++
#     スター: 37
#
# 14. webview-ads
#     言語: HTML
#     スター: 1
#
# 15. gematria
#     言語: Python
#     スター: 91
#
# 16. taxinomia
#     言語: Go
#     スター: 1
#
# 17. opendocs
#     言語: 不明
#     スター: 199
#
# 18. jaxopt
#     言語: Python
#     スター: 1000
#
# 19. threat-team
#     言語: YARA
#     スター: 54
#
# 20. generative-ai-docs
#     言語: Jupyter Notebook
#     スター: 2200
#
# 21. oss-policies-info
#     言語: 不明
#     スター: 28
#
# 22. cloud-forensics-utils
#     言語: Python
#     スター: 489
#
# 23. play-unreal-engine-plugin
#     言語: C++
#     スター: 12
#
# 24. security-testbeds
#     言語: Tcl
#     スター: 52
#
# 25. amber
#     言語: C++
#     スター: 214
#
# 26. proto-lens
#     言語: Haskell
#     スター: 497
#
# 27. play-services-plugins
#     言語: Java
#     スター: 503
#
# 28. packetdrill
#     言語: C
#     スター: 950
#
# 29. codemirror.dart
#     言語: Dart
#     スター: 87
#
# 30. emboss
#     言語: Python
#     スター: 82
#
# ページ 16 完了: 30件取得 (累計: 480件)
# ----------------------------------------------------------------------
#
# Page 17:
# 1. playground-elements
#     言語: TypeScript
#     スター: 625
#
# 2. snippet-uiautomator
#     言語: Java
#     スター: 46
#
# 3. slowjam
#     言語: HTML
#     スター: 252
#
# 4. fswalker
#     言語: Go
#     スター: 109
#
# 5. sanitizers
#     言語: C
#     スター: 12000
#
# 6. reflectable.dart
#     言語: Dart
#     スター: 382
#
# 7. private-compute-services
#     言語: Java
#     スター: 531
#
# 8. llm-sidebar-with-context
#     言語: JavaScript
#     スター: 4
#
# 9. mediapy
#     言語: Jupyter Notebook
#     スター: 440
#
# 10. learn-oss-with-google
#     言語: Python
#     スター: 43
#
# 11. google.github.io
#     言語: HTML
#     スター: 533
#
# 12. minimalloc
#     言語: C++
#     スター: 175
#
# 13. smccc
#     言語: Rust
#     スター: 8
#
# 14. s2a-proto
#     言語: 不明
#     スター: 0
#
# 15. s2a-go
#     言語: Go
#     スター: 25
#
# 16. GoogleUtilities
#     言語: Objective-C
#     スター: 121
#
# 17. mount-zip
#     言語: C++
#     スター: 221
#
# 18. dnsmasq_exporter
#     言語: Go
#     スター: 184
#
# 19. libultrahdr
#     言語: C++
#     スター: 263
#
# 20. GTMAppAuth
#     言語: Swift
#     スター: 413
#
# 21. ffn
#     言語: Python
#     スター: 339
#
# 22. trax
#     言語: Python
#     スター: 8300
#
# 23. mobly-wifi
#     言語: Python
#     スター: 7
#
# 24. CausalImpact
#     言語: R
#     スター: 1800
#
# 25. create-service-account
#     言語: Python
#     スター: 25
#
# 26. wmt-mqm-human-evaluation
#     言語: 不明
#     スター: 96
#
# 27. polymorphicDSL
#     言語: Java
#     スター: 12
#
# 28. apitools
#     言語: Python
#     スター: 145
#
# 29. flink-connector-gcp
#     言語: Java
#     スター: 12
#
# 30. bundletool
#     言語: Java
#     スター: 3900
#
# ページ 17 完了: 30件取得 (累計: 510件)
# ----------------------------------------------------------------------
#
# Page 18:
# 1. rdma-unit-test
#     言語: C++
#     スター: 30
#
# 2. GiftStick
#     言語: Python
#     スター: 142
#
# 3. minja
#     言語: C++
#     スター: 198
#
# 4. gin-config
#     言語: Python
#     スター: 2100
#
# 5. quahog
#     言語: Go
#     スター: 2
#
# 6. sagetv
#     言語: Java
#     スター: 280
#
# 7. protobuf-gradle-plugin
#     言語: Groovy
#     スター: 1800
#
# 8. struct2tensor
#     言語: Python
#     スター: 34
#
# 9. material-design-icons
#     言語: 不明
#     スター: 53000
#
# 10. closure-compiler-npm
#     言語: JavaScript
#     スター: 339
#
# 11. allocation-instrumenter
#     言語: Java
#     スター: 487
#
# 12. draco
#     言語: C++
#     スター: 7000
#
# 13. jscin
#     言語: JavaScript
#     スター: 45
#
# 14. kati
#     言語: Rust
#     スター: 994
#
# 15. GoogleDataTransport
#     言語: Objective-C
#     スター: 53
#
# 16. cql
#     言語: Go
#     スター: 94
#
# 17. interop-ios-for-google-sdks
#     言語: Objective-C
#     スター: 13
#
# 18. app-check
#     言語: Objective-C
#     スター: 31
#
# 19. fully-homomorphic-encryption
#     言語: C++
#     スター: 3600
#
# 20. strict-csp
#     言語: TypeScript
#     スター: 48
#
# 21. jaxonnxruntime
#     言語: Python
#     スター: 125
#
# 22. subcommands
#     言語: Go
#     スター: 784
#
# 23. ukey2
#     言語: Java
#     スター: 48
#
# 24. dataflow-ml-starter
#     言語: Python
#     スター: 24
#
# 25. async-request-dispatcher-rs
#     言語: Rust
#     スター: 3
#
# 26. virtual-broadcast-production-assistant
#     言語: JavaScript
#     スター: 17
#
# 27. honggfuzz
#     言語: C
#     スター: 3300
#
# 28. kctf
#     言語: Go
#     スター: 731
#
# 29. gcp_scanner
#     言語: Python
#     スター: 341
#
# 30. bigwheels
#     言語: C++
#     スター: 101
#
# ページ 18 完了: 30件取得 (累計: 540件)
# ----------------------------------------------------------------------
#
# Page 19:
# 1. web-game-samples
#     言語: JavaScript
#     スター: 59
#
# 2. fleetspeak-rs
#     言語: Rust
#     スター: 10
#
# 3. eng-edu
#     言語: Jupyter Notebook
#     スター: 734
#
# 4. edward2
#     言語: Jupyter Notebook
#     スター: 702
#
# 5. fuse-archive
#     言語: C++
#     スター: 223
#
# 6. github-webhook-pubsub-bridge
#     言語: Go
#     スター: 6
#
# 7. safe-mmio
#     言語: Rust
#     スター: 17
#
# 8. go-licenses
#     言語: Go
#     スター: 961
#
# 9. pybind11clif
#     言語: C++
#     スター: 70
#
# 10. shaderc-rs
#     言語: Rust
#     スター: 282
#
# 11. closure-net
#     言語: 不明
#     スター: 3
#
# 12. rax
#     言語: Python
#     スター: 335
#
# 13. go-dap
#     言語: Go
#     スター: 133
#
# 14. distributed_point_functions
#     言語: C++
#     スター: 77
#
# 15. rust-scudo
#     言語: Rust
#     スター: 59
#
# 16. casimir
#     言語: Rust
#     スター: 1
#
# 17. ota-analyzer
#     言語: JavaScript
#     スター: 13
#
# 18. crumbles
#     言語: Java
#     スター: 5
#
# 19. tuple.dart
#     言語: Dart
#     スター: 194
#
# 20. grinder.dart
#     言語: Dart
#     スター: 266
#
# 21. webdriver.dart
#     言語: Dart
#     スター: 141
#
# 22. sync_http.dart
#     言語: Dart
#     スター: 17
#
# 23. flutter-mediapipe
#     言語: Dart
#     スター: 270
#
# 24. dart-basics
#     言語: Dart
#     スター: 164
#
# 25. genc
#     言語: C++
#     スター: 63
#
# 26. carfac
#     言語: Jupyter Notebook
#     スター: 131
#
# 27. kube-startup-cpu-boost
#     言語: Go
#     スター: 508
#
# 28. jni-bind
#     言語: C++
#     スター: 303
#
# 29. autocxx
#     言語: Rust
#     スター: 2500
#
# 30. ghc-source-gen
#     言語: Haskell
#     スター: 99
#
# ページ 19 完了: 30件取得 (累計: 570件)
# ----------------------------------------------------------------------
#
# Page 20:
# 1. tsunami-security-scanner-callback-server
#     言語: Java
#     スター: 18
#
# 2. partner-ads-experience
#     言語: 不明
#     スター: 4
#
# 3. fast-isotropic-median-filter
#     言語: C++
#     スター: 16
#
# 4. ink-stroke-modeler
#     言語: C++
#     スター: 104
#
# 5. cad_campaign_anomaly_detector
#     言語: JavaScript
#     スター: 11
#
# 6. pcie_lmt
#     言語: Go
#     スター: 7
#
# 7. llvm-memprof
#     言語: C++
#     スター: 4
#
# 8. soql-tool
#     言語: Apex
#     スター: 0
#
# 9. pl011-uart
#     言語: Rust
#     スター: 6
#
# 10. saif-data
#     言語: 不明
#     スター: 4
#
# 11. link-diver
#     言語: TypeScript
#     スター: 69
#
# 12. wire
#     言語: Go
#     スター: 14000
#
# 13. grpc-binary
#     言語: Swift
#     スター: 10
#
# 14. kunit-docs
#     言語: HTML
#     スター: 29
#
# 15. evolve-forms
#     言語: Apex
#     スター: 175
#
# 16. matched_markets
#     言語: Python
#     スター: 94
#
# 17. flow-lens
#     言語: TypeScript
#     スター: 72
#
# 18. distributed_graph_flow
#     言語: 不明
#     スター: 0
#
# 19. go-eventlog
#     言語: Go
#     スター: 15
#
# 20. Serberus
#     言語: 不明
#     スター: 13
#
# 21. node-gles
#     言語: C++
#     スター: 331
#
# 22. co-op-4-all
#     言語: TypeScript
#     スター: 10
#
# 23. data-driven-discretization-1d
#     言語: Jupyter Notebook
#     スター: 168
#
# 24. howtodiv
#     言語: Python
#     スター: 8
#
# 25. corpuscrawler
#     言語: Python
#     スター: 211
#
# 26. accompanist
#     言語: Kotlin
#     スター: 7800
#
# 27. proto-task-queue
#     言語: Python
#     スター: 10
#
# 28. arm-gic
#     言語: Rust
#     スター: 38
#
# 29. python-spanner-orm
#     言語: Python
#     スター: 40
#
# 30. multichase
#     言語: C
#     スター: 146
#
# ページ 20 完了: 30件取得 (累計: 600件)
# ----------------------------------------------------------------------
#
# Page 21:
# 1. graph-mining
#     言語: C++
#     スター: 712
#
# 2. executor.nvim
#     言語: Lua
#     スター: 153
#
# 3. s2-geometry-library-java
#     言語: Java
#     スター: 578
#
# 4. gnostic
#     言語: Go
#     スター: 2200
#
# 5. cluster-data
#     言語: TeX
#     スター: 1000
#
# 6. speaker-id
#     言語: Python
#     スター: 436
#
# 7. localtoast
#     言語: Go
#     スター: 114
#
# 8. generative-ai-go
#     言語: Go
#     スター: 830
#
# 9. if-this-then-ad
#     言語: TypeScript
#     スター: 99
#
# 10. dynamicworld
#     言語: Jupyter Notebook
#     スター: 153
#
# 11. effcee
#     言語: C++
#     スター: 102
#
# 12. facade
#     言語: Python
#     スター: 134
#
# 13. har2csv
#     言語: JavaScript
#     スター: 46
#
# 14. reflow-list
#     言語: TypeScript
#     スター: 8
#
# 15. model-viewer
#     言語: TypeScript
#     スター: 7700
#
# 16. esamplusplus
#     言語: Python
#     スター: 4
#
# 17. devlibrary
#     言語: Vue
#     スター: 194
#
# 18. shoptimizer
#     言語: Python
#     スター: 48
#
# 19. safe-active-record
#     言語: Ruby
#     スター: 18
#
# 20. practical-inverse-rendering-of-textured-and-translucent-appearance
#     言語: Python
#     スター: 113
#
# 21. deluca
#     言語: Jupyter Notebook
#     スター: 124
#
# 22. wci
#     言語: Python
#     スター: 36
#
# 23. csv-to-firestore
#     言語: Python
#     スター: 25
#
# 24. tacotron
#     言語: HTML
#     スター: 540
#
# 25. sequence-layers
#     言語: Python
#     スター: 46
#
# 26. conversational-surveys
#     言語: JavaScript
#     スター: 6
#
# 27. ippusb
#     言語: Rust
#     スター: 4
#
# 28. rubik
#     言語: Python
#     スター: 28
#
# 29. vbootrom
#     言語: C
#     スター: 16
#
# 30. web-hv
#     言語: JavaScript
#     スター: 46
#
# ページ 21 完了: 30件取得 (累計: 630件)
# ----------------------------------------------------------------------
#
# Page 22:
# 1. safety-web
#     言語: TypeScript
#     スター: 27
#
# 2. argh
#     言語: Rust
#     スター: 1900
#
# 3. fedjax
#     言語: Python
#     スター: 266
#
# 4. jsonnet
#     言語: Jsonnet
#     スター: 7400
#
# 5. chrome-ssh-agent
#     言語: Go
#     スター: 274
#
# 6. hrx-ruby
#     言語: Ruby
#     スター: 12
#
# 7. smc-hello-world
#     言語: C
#     スター: 1
#
# 8. smc-common
#     言語: C
#     スター: 1
#
# 9. deku
#     言語: Go
#     スター: 6
#
# 10. code-review-bot
#     言語: Go
#     スター: 101
#
# 11. truestreet
#     言語: Go
#     スター: 42
#
# 12. python-card-framework
#     言語: Python
#     スター: 22
#
# 13. ruy
#     言語: C++
#     スター: 316
#
# 14. gmail-oauth2-tools
#     言語: Python
#     スター: 464
#
# 15. triage-party
#     言語: Go
#     スター: 521
#
# 16. web-api-gateway
#     言語: Go
#     スター: 46
#
# 17. payjs
#     言語: JavaScript
#     スター: 7
#
# 18. gonids
#     言語: Go
#     スター: 189
#
# 19. flyweights
#     言語: Rust
#     スター: 2
#
# 20. litmus
#     言語: Vue
#     スター: 38
#
# 21. gtest-parallel
#     言語: Python
#     スター: 454
#
# 22. ml-edu
#     言語: Python
#     スター: 6
#
# 23. automotive-design-compose-protos
#     言語: 不明
#     スター: 0
#
# 24. swissgl
#     言語: JavaScript
#     スター: 1200
#
# 25. rde-tester
#     言語: C++
#     スター: 1
#
# 26. refvnli
#     言語: JavaScript
#     スター: 0
#
# 27. CoMMA
#     言語: Rust
#     スター: 10
#
# 28. fsl-gaming
#     言語: JavaScript
#     スター: 25
#
# 29. terraform-google-sqlserver
#     言語: PowerShell
#     スター: 3
#
# 30. cost-attribution-solution
#     言語: HCL
#     スター: 37
#
# ページ 22 完了: 30件取得 (累計: 660件)
# ----------------------------------------------------------------------
#
# Page 23:
# 1. lmeval
#     言語: Python
#     スター: 235
#
# 2. tachometer
#     言語: TypeScript
#     スター: 726
#
# 3. ios-webkit-debug-proxy
#     言語: C
#     スター: 6100
#
# 4. apilark
#     言語: 不明
#     スター: 6
#
# 5. tcli
#     言語: Python
#     スター: 9
#
# 6. app-resource-bundle
#     言語: 不明
#     スター: 155
#
# 7. recaptcha
#     言語: PHP
#     スター: 3500
#
# 8. ent
#     言語: Go
#     スター: 75
#
# 9. CommonLoopUtils
#     言語: Jupyter Notebook
#     スター: 358
#
# 10. ebpf-transport-monitoring
#     言語: Go
#     スター: 23
#
# 11. rago
#     言語: Python
#     スター: 21
#
# 12. aukera
#     言語: Go
#     スター: 41
#
# 13. open-location-code
#     言語: Java
#     スター: 4300
#
# 14. jaxcam
#     言語: Python
#     スター: 13
#
# 15. content_recommendation_using_word2vec
#     言語: Python
#     スター: 27
#
# 16. safehtml
#     言語: Go
#     スター: 373
#
# 17. forest-data-partnership
#     言語: Jupyter Notebook
#     スター: 35
#
# 18. lightweight_mmm
#     言語: Python
#     スター: 1000
#
# 19. gazoo-device
#     言語: Python
#     スター: 23
#
# 20. bt-test-interfaces
#     言語: Python
#     スター: 14
#
# 21. avatar
#     言語: Python
#     スター: 20
#
# 22. paranoid_crypto
#     言語: Python
#     スター: 796
#
# 23. proto-splitter
#     言語: C++
#     スター: 1
#
# 24. cadvisor
#     言語: Go
#     スター: 19000
#
# 25. unblocking-detail-caption
#     言語: HTML
#     スター: 1
#
# 26. auto-arborist
#     言語: Jupyter Notebook
#     スター: 13
#
# 27. qkeras
#     言語: Python
#     スター: 578
#
# 28. pts-bot
#     言語: Rust
#     スター: 4
#
# 29. vroom
#     言語: Python
#     スター: 274
#
# 30. libaddressinput
#     言語: C++
#     スター: 606
#
# ページ 23 完了: 30件取得 (累計: 690件)
# ----------------------------------------------------------------------
#
# Page 24:
# 1. android-key-attestation
#     言語: Java
#     スター: 213
#
# 2. dv360-duplicator
#     言語: TypeScript
#     スター: 20
#
# 3. eiffel
#     言語: C
#     スター: 5
#
# 4. skyline_rl_lab
#     言語: Jupyter Notebook
#     スター: 6
#
# 5. pseudo-identity-provider
#     言語: Go
#     スター: 9
#
# 6. llvm-premerge-checks
#     言語: Python
#     スター: 43
#
# 7. go-configfs-tsm
#     言語: Go
#     スター: 8
#
# 8. grr
#     言語: Python
#     スター: 5000
#
# 9. sandwiched_compression
#     言語: Jupyter Notebook
#     スター: 48
#
# 10. gemma_pytorch
#     言語: Python
#     スター: 5600
#
# 11. go-safeweb
#     言語: Go
#     スター: 1500
#
# 12. visualblocks
#     言語: TypeScript
#     スター: 1300
#
# 13. codesearch
#     言語: Go
#     スター: 3900
#
# 14. webauthndemo
#     言語: TypeScript
#     スター: 621
#
# 15. UIforETW
#     言語: C++
#     スター: 1600
#
# 16. hiba
#     言語: C
#     スター: 384
#
# 17. pyink
#     言語: Python
#     スター: 280
#
# 18. vk-layer-for-rust
#     言語: Rust
#     スター: 14
#
# 19. liblc3
#     言語: C
#     スター: 225
#
# 20. taqo-paco
#     言語: Dart
#     スター: 12
#
# 21. jse4conf
#     言語: Java
#     スター: 6
#
# 22. synthmark
#     言語: C++
#     スター: 56
#
# 23. df-conformer
#     言語: HTML
#     スター: 31
#
# 24. zetasketch
#     言語: Java
#     スター: 163
#
# 25. cairn
#     言語: C++
#     スター: 5
#
# 26. agi
#     言語: Go
#     スター: 1000
#
# 27. lullaby
#     言語: C++
#     スター: 1200
#
# 28. visqol
#     言語: C++
#     スター: 836
#
# 29. glog
#     言語: C++
#     スター: 7300
#
# 30. uvq
#     言語: Python
#     スター: 119
#
# ページ 24 完了: 30件取得 (累計: 720件)
# ----------------------------------------------------------------------
#
# Page 25:
# 1. aegis_cipher
#     言語: C++
#     スター: 25
#
# 2. consent-based-conversion-adjustments
#     言語: Python
#     スター: 25
#
# 3. containerdbg
#     言語: C
#     スター: 74
#
# 4. Stereoscopic-Video-Generation-via-Denoising-Frame-Matrix
#     言語: Python
#     スター: 8
#
# 5. iopddl
#     言語: C++
#     スター: 24
#
# 6. badwolf-drivers
#     言語: Go
#     スター: 22
#
# 7. project-euphonia-app
#     言語: Dart
#     スター: 29
#
# 8. badwolf
#     言語: Go
#     スター: 984
#
# 9. fruit
#     言語: C++
#     スター: 1900
#
# 10. sa360-bigquery-bootstrapper
#     言語: Python
#     スター: 6
#
# 11. gemma-unity-plugin
#     言語: C#
#     スター: 79
#
# 12. gemma-journey
#     言語: C#
#     スター: 28
#
# 13. feabench
#     言語: Python
#     スター: 4
#
# 14. hashr
#     言語: Go
#     スター: 126
#
# 15. regexpand
#     言語: Go
#     スター: 8
#
# 16. myelin-acorn-electron-hardware
#     言語: Python
#     スター: 59
#
# 17. vscode-vnc
#     言語: TypeScript
#     スター: 5
#
# 18. pica
#     言語: Python
#     スター: 55
#
# 19. strangemeadowlark
#     言語: Rust
#     スター: 3
#
# 20. note-maps
#     言語: Go
#     スター: 129
#
# 21. curie
#     言語: Jupyter Notebook
#     スター: 28
#
# 22. mobly-cros
#     言語: Python
#     スター: 2
#
# 23. go-tika
#     言語: Go
#     スター: 253
#
# 24. textfsm
#     言語: Python
#     スター: 1200
#
# 25. sherlock
#     言語: Python
#     スター: 8
#
# 26. go-tspi
#     言語: Go
#     スター: 62
#
# 27. kernel-sanitizers
#     言語: Python
#     スター: 468
#
# 28. file-header
#     言語: Rust
#     スター: 19
#
# 29. extra-keyboards-for-chrome-os
#     言語: JavaScript
#     スター: 214
#
# 30. libprotobuf-mutator
#     言語: C++
#     スター: 633
#
# ページ 25 完了: 30件取得 (累計: 750件)
# ----------------------------------------------------------------------
#
# Page 26:
# 1. crc32c
#     言語: C++
#     スター: 498
#
# 2. codeworld
#     言語: Haskell
#     スター: 1300
#
# 3. smali
#     言語: Java
#     スター: 325
#
# 4. android-riscv64
#     言語: 不明
#     スター: 242
#
# 5. unisim
#     言語: Python
#     スター: 144
#
# 6. ml-metadata
#     言語: C++
#     スター: 666
#
# 7. kmsan
#     言語: C
#     スター: 417
#
# 8. play-asset-delivery-unity
#     言語: C#
#     スター: 13
#
# 9. play-appbundle-unity
#     言語: C#
#     スター: 8
#
# 10. file-based-test-driver
#     言語: C++
#     スター: 13
#
# 11. oauth2l
#     言語: Go
#     スター: 709
#
# 12. ads-privacy
#     言語: 不明
#     スター: 408
#
# 13. trusted-types-helper
#     言語: TypeScript
#     スター: 11
#
# 14. search-in-apps
#     言語: Swift
#     スター: 4
#
# 15. eslint-config-google
#     言語: JavaScript
#     スター: 1800
#
# 16. go-replayers
#     言語: Go
#     スター: 432
#
# 17. uVkCompute
#     言語: C++
#     スター: 257
#
# 18. dfdewey
#     言語: Python
#     スター: 19
#
# 19. CFU-Playground
#     言語: Verilog
#     スター: 535
#
# 20. sqlcommenter
#     言語: PHP
#     スター: 616
#
# 21. picatrix
#     言語: Python
#     スター: 51
#
# 22. shadertrap
#     言語: C++
#     スター: 12
#
# 23. lldb-eval
#     言語: C++
#     スター: 86
#
# 24. pasta
#     言語: Python
#     スター: 359
#
# 25. LogicLM
#     言語: HTML
#     スター: 29
#
# 26. wuffs-mirror-release-c
#     言語: C
#     スター: 39
#
# 27. image_mix
#     言語: Python
#     スター: 16
#
# 28. page-alloc-bench
#     言語: Go
#     スター: 4
#
# 29. grizzly
#     言語: Python
#     スター: 69
#
# 30. tf-quant-finance
#     言語: Python
#     スター: 5100
#
# ページ 26 完了: 30件取得 (累計: 780件)
# ----------------------------------------------------------------------
#
# Page 27:
# 1. coding-with-chrome
#     言語: JavaScript
#     スター: 530
#
# 2. html-to-jsonld-converter
#     言語: Python
#     スター: 5
#
# 3. gopacket
#     言語: Go
#     スター: 6700
#
# 4. RB-Modulation
#     言語: Jupyter Notebook
#     スター: 402
#
# 5. briolette
#     言語: Rust
#     スター: 67
#
# 6. bbr
#     言語: 不明
#     スター: 5800
#
# 7. py-lab-hal
#     言語: Python
#     スター: 12
#
# 8. bsynth
#     言語: C++
#     スター: 20
#
# 9. .github
#     言語: 不明
#     スター: 109
#
# 10. snowflake-to-bq-data-transfer-tool
#     言語: Java
#     スター: 3
#
# 11. password-alert
#     言語: JavaScript
#     スター: 322
#
# 12. moodle-on-gcp
#     言語: Shell
#     スター: 72
#
# 13. glance-experimental-tools
#     言語: Kotlin
#     スター: 185
#
# 14. myanmar-tools
#     言語: Java
#     スター: 255
#
# 15. k8s-digester
#     言語: Go
#     スター: 155
#
# 16. splice
#     言語: Go
#     スター: 65
#
# 17. cc-device-plugin
#     言語: Go
#     スター: 4
#
# 18. project-OCEAN
#     言語: Python
#     スター: 55
#
# 19. git-pull-request-mirror
#     言語: Go
#     スター: 95
#
# 20. weasel
#     言語: Go
#     スター: 66
#
# 21. parse-ego4d
#     言語: Jupyter Notebook
#     スター: 7
#
# 22. deepconsensus
#     言語: Python
#     スター: 252
#
# 23. deeppolisher
#     言語: Jupyter Notebook
#     スター: 94
#
# 24. makerspace-auth
#     言語: Python
#     スター: 66
#
# 25. material-design-lite
#     言語: HTML
#     スター: 32000
#
# 26. patrick
#     言語: R
#     スター: 143
#
# 27. xr-objects
#     言語: C#
#     スター: 161
#
# 28. dlc-insight-lab
#     言語: JavaScript
#     スター: 1
#
# 29. j2cl-protobuf
#     言語: JavaScript
#     スター: 25
#
# 30. yarsa
#     言語: Go
#     スター: 1
#
# ページ 27 完了: 30件取得 (累計: 810件)
# ----------------------------------------------------------------------
#
# Page 28:
# 1. googlesre
#     言語: TypeScript
#     スター: 167
#
# 2. android-auto-companion-android
#     言語: Kotlin
#     スター: 26
#
# 3. automl
#     言語: Jupyter Notebook
#     スター: 6400
#
# 4. gdb_gcore_point
#     言語: Python
#     スター: 2
#
# 5. serde_json5
#     言語: Rust
#     スター: 42
#
# 6. emoji-scavenger-hunt
#     言語: TypeScript
#     スター: 819
#
# 7. android-auto-companion-ios
#     言語: Swift
#     スター: 16
#
# 8. library-wrapper-unity-common
#     言語: C#
#     スター: 7
#
# 9. lottie-tools
#     言語: Rust
#     スター: 2
#
# 10. speedy
#     言語: C++
#     スター: 35
#
# 11. pebble
#     言語: C
#     スター: 4900
#
# 12. volley
#     言語: Java
#     スター: 3400
#
# 13. open-sztp
#     言語: Go
#     スター: 11
#
# 14. pyu2f
#     言語: Python
#     スター: 84
#
# 15. marl
#     言語: C++
#     スター: 2000
#
# 16. cppdap
#     言語: C++
#     スター: 182
#
# 17. uem_poc
#     言語: TypeScript
#     スター: 3
#
# 18. new-project
#     言語: 不明
#     スター: 234
#
# 19. go-cmp
#     言語: Go
#     スター: 4500
#
# 20. mlir-hs
#     言語: Haskell
#     スター: 118
#
# 21. webrisk
#     言語: Go
#     スター: 78
#
# 22. csp-evaluator
#     言語: TypeScript
#     スター: 373
#
# 23. multichannel-audio-tools
#     言語: C++
#     スター: 95
#
# 24. pprof-nodejs
#     言語: JavaScript
#     スター: 287
#
# 25. hctr2
#     言語: C
#     スター: 37
#
# 26. santa-tracker-web
#     言語: JavaScript
#     スター: 644
#
# 27. jira-to-issues
#     言語: TypeScript
#     スター: 18
#
# 28. best
#     言語: Rust
#     スター: 137
#
# 29. alu-api
#     言語: Jupyter Notebook
#     スター: 1
#
# 30. haskell-indexer
#     言語: Haskell
#     スター: 101
#
# ページ 28 完了: 30件取得 (累計: 840件)
# ----------------------------------------------------------------------
#
# Page 29:
# 1. latexify_py
#     言語: Python
#     スター: 7600
#
# 2. abseil-cpp-binary
#     言語: Swift
#     スター: 16
#
# 3. fuzzbench
#     言語: Python
#     スター: 1200
#
# 4. jarjar
#     言語: Java
#     スター: 90
#
# 5. xdtk
#     言語: Java
#     スター: 38
#
# 6. play-integrity-unity
#     言語: C#
#     スター: 10
#
# 7. play-in-app-reviews-unity
#     言語: C#
#     スター: 12
#
# 8. play-in-app-updates-unity
#     言語: C#
#     スター: 3
#
# 9. santa
#     言語: Objective-C++
#     スター: 4500
#
# 10. play-core-unity
#     言語: C#
#     スター: 3
#
# 11. android-auto-companion-app
#     言語: Dart
#     スター: 15
#
# 12. orbit
#     言語: C++
#     スター: 4300
#
# 13. leveldb
#     言語: C++
#     スター: 38000
#
# 14. ctrdac
#     言語: Go
#     スター: 13
#
# 15. mail-importer
#     言語: Java
#     スター: 264
#
# 16. deck
#     言語: Go
#     スター: 56
#
# 17. unsmear
#     言語: C++
#     スター: 95
#
# 18. library-wrapper-unity-openjdk8
#     言語: C#
#     スター: 7
#
# 19. calblink
#     言語: Go
#     スター: 43
#
# 20. kir-holiday-lights
#     言語: Shell
#     スター: 19
#
# 21. io-connect-2024-ui-workshop
#     言語: CSS
#     スター: 44
#
# 22. snaplayout-for-xmonad
#     言語: Haskell
#     スター: 6
#
# 23. dfiq
#     言語: Python
#     スター: 294
#
# 24. git-tree
#     言語: Rust
#     スター: 45
#
# 25. learn_unsafe_rust
#     言語: 不明
#     スター: 279
#
# 26. archat
#     言語: TypeScript
#     スター: 94
#
# 27. summit-ast
#     言語: Kotlin
#     スター: 42
#
# 28. rust-p9
#     言語: Rust
#     スター: 43
#
# 29. spiqa
#     言語: Python
#     スター: 70
#
# 30. oxsea
#     言語: Rust
#     スター: 2
#
# ページ 29 完了: 30件取得 (累計: 870件)
# ----------------------------------------------------------------------
#
# Page 30:
# 1. re2j
#     言語: Java
#     スター: 1200
#
# 2. megalista
#     言語: Python
#     スター: 138
#
# 3. serde_json_lenient
#     言語: Rust
#     スター: 25
#
# 4. bulk-actions-framework
#     言語: Apex
#     スター: 1
#
# 5. rag-playground
#     言語: Python
#     スター: 41
#
# 6. agi-dev-releases
#     言語: Shell
#     スター: 35
#
# 7. fhir-app-examples
#     言語: Kotlin
#     スター: 54
#
# 8. shopping_insider
#     言語: Python
#     スター: 29
#
# 9. gnostic-grpc
#     言語: Go
#     スター: 314
#
# 10. acjs
#     言語: Go
#     スター: 10
#
# 11. go-react
#     言語: Go
#     スター: 38
#
# 12. broken-dns
#     言語: Go
#     スター: 22
#
# 13. xtoproto
#     言語: Go
#     スター: 58
#
# 14. martian
#     言語: Go
#     スター: 2000
#
# 15. recursive-version-control-system
#     言語: Go
#     スター: 31
#
# 16. spdmd
#     言語: C++
#     スター: 0
#
# 17. bulk_fhir_tools
#     言語: Go
#     スター: 63
#
# 18. ondc-opencommerce
#     言語: Go
#     スター: 24
#
# 19. goblet
#     言語: Go
#     スター: 181
#
# 20. webpackager
#     言語: Go
#     スター: 75
#
# 21. apt-golang-s3
#     言語: Go
#     スター: 49
#
# 22. fhir-dbt-analytics
#     言語: Shell
#     スター: 58
#
# 23. vxsig
#     言語: C++
#     スター: 284
#
# 24. traceur-compiler
#     言語: JavaScript
#     スター: 8200
#
# 25. vimscript-language-server
#     言語: Rust
#     スター: 401
#
# 26. cpp-from-the-sky-down
#     言語: HTML
#     スター: 276
#
# 27. tree-math
#     言語: Python
#     スター: 202
#
# 28. go-streaming-globber
#     言語: Go
#     スター: 6
#
# 29. clusterfuzzlite
#     言語: 不明
#     スター: 509
#
# 30. ads-bi-suite
#     言語: Shell
#     スター: 18
#
# ページ 30 完了: 30件取得 (累計: 900件)
# ----------------------------------------------------------------------
#
# Page 31:
# 1. tcpgpudmarxd
#     言語: C++
#     スター: 9
#
# 2. play-common-unity
#     言語: C#
#     スター: 1
#
# 3. play-unity-plugins
#     言語: C#
#     スター: 465
#
# 4. codex
#     言語: Jupyter Notebook
#     スター: 67
#
# 5. sre_yield
#     言語: Python
#     スター: 187
#
# 6. lintush
#     言語: JavaScript
#     スター: 59
#
# 7. emoji-segmenter
#     言語: C
#     スター: 64
#
# 8. unity-anr-plugin
#     言語: Java
#     スター: 5
#
# 9. imageinwords
#     言語: JavaScript
#     スター: 223
#
# 10. android-emulator-container-scripts
#     言語: Python
#     スター: 2000
#
# 11. werm
#     言語: C
#     スター: 46
#
# 12. season-of-docs
#     言語: 不明
#     スター: 579
#
# 13. uuid
#     言語: Go
#     スター: 5900
#
# 14. android-auto-companion-calendarsync-ios
#     言語: Swift
#     スター: 6
#
# 15. ionosphere
#     言語: Jupyter Notebook
#     スター: 3
#
# 16. takeout
#     言語: 不明
#     スター: 11
#
# 17. promises
#     言語: Objective-C
#     スター: 3800
#
# 18. iba-opt-out-plugin
#     言語: JavaScript
#     スター: 1
#
# 19. dopamine
#     言語: Jupyter Notebook
#     スター: 11000
#
# 20. docci
#     言語: HTML
#     スター: 3
#
# 21. compute-virtual-ethernet-dpdk
#     言語: C
#     スター: 11
#
# 22. angular-directed-graph
#     言語: TypeScript
#     スター: 18
#
# 23. skywater-pdk
#     言語: Python
#     スター: 3300
#
# 24. safearchive
#     言語: Go
#     スター: 64
#
# 25. gts
#     言語: TypeScript
#     スター: 5200
#
# 26. fuzzing
#     言語: C++
#     スター: 3700
#
# 27. slang-gaussian-rasterization
#     言語: Python
#     スター: 362
#
# 28. talkback
#     言語: Java
#     スター: 488
#
# 29. langsvr
#     言語: C++
#     スター: 9
#
# 30. coroutine-stacks
#     言語: Kotlin
#     スター: 144
#
# ページ 31 完了: 30件取得 (累計: 930件)
# ----------------------------------------------------------------------
#
# Page 32:
# 1. devtools-driver
#     言語: Java
#     スター: 16
#
# 2. account-provisioning-for-google-apps
#     言語: Java
#     スター: 51
#
# 3. chicago-brick
#     言語: TypeScript
#     スター: 161
#
# 4. tour-of-wgsl
#     言語: TypeScript
#     スター: 142
#
# 5. crfs
#     言語: Go
#     スター: 1400
#
# 6. cql-on-beam
#     言語: Java
#     スター: 12
#
# 7. capsicum-test
#     言語: C++
#     スター: 45
#
# 8. docker-explorer
#     言語: Python
#     スター: 548
#
# 9. graphicsfuzz
#     言語: Java
#     スター: 595
#
# 10. CodeCity
#     言語: JavaScript
#     スター: 193
#
# 11. moriarty
#     言語: C++
#     スター: 6
#
# 12. uis-rnn
#     言語: Python
#     スター: 1600
#
# 13. purr
#     言語: Shell
#     スター: 155
#
# 14. karma-webkit-launcher
#     言語: JavaScript
#     スター: 12
#
# 15. yaml-ui-editor
#     言語: Java
#     スター: 32
#
# 16. supl-client
#     言語: Java
#     スター: 71
#
# 17. robotstxt-spec-test
#     言語: Java
#     スター: 23
#
# 18. step49-2020
#     言語: Java
#     スター: 3
#
# 19. robotstxt-java
#     言語: Java
#     スター: 47
#
# 20. exposure-notifications-private-analytics-ingestion
#     言語: Java
#     スター: 12
#
# 21. play-work
#     言語: Java
#     スター: 85
#
# 22. grr-doc
#     言語: Shell
#     スター: 307
#
# 23. eng-practices
#     言語: 不明
#     スター: 20000
#
# 24. tec-web-assignments
#     言語: JavaScript
#     スター: 12
#
# 25. webdriver-shadow-dom
#     言語: Kotlin
#     スター: 2
#
# 26. drive-file-search-fix
#     言語: JavaScript
#     スター: 5
#
# 27. gousb
#     言語: Go
#     スター: 919
#
# 28. bayesnf
#     言語: Python
#     スター: 142
#
# 29. funke-eudi-wallet-prototype
#     言語: Kotlin
#     スター: 3
#
# 30. vimdoc
#     言語: Python
#     スター: 304
#
# ページ 32 完了: 30件取得 (累計: 960件)
# ----------------------------------------------------------------------
#
# Page 33:
# 1. paseos
#     言語: JavaScript
#     スター: 15
#
# 2. tsunami
#     言語: TypeScript
#     スター: 9
#
# 3. hrx
#     言語: SCSS
#     スター: 49
#
# 4. english--
#     言語: JavaScript
#     スター: 7
#
# 5. clif
#     言語: C++
#     スター: 981
#
# 6. grrshell
#     言語: Python
#     スター: 7
#
# 7. cdc-file-transfer
#     言語: C++
#     スター: 3400
#
# 8. devops-governance
#     言語: 不明
#     スター: 83
#
# 9. google-visualization
#     言語: TypeScript
#     スター: 14
#
# 10. price_visibility_booster
#     言語: JavaScript
#     スター: 2
#
# 11. vim-codefmt
#     言語: Vim Script
#     スター: 1100
#
# 12. project-gameface
#     言語: Java
#     スター: 617
#
# 13. Vulkan-Errata
#     言語: Python
#     スター: 5
#
# 14. ad_language_monitor
#     言語: JavaScript
#     スター: 5
#
# 15. cell_img
#     言語: Jupyter Notebook
#     スター: 8
#
# 16. souper
#     言語: C++
#     スター: 2300
#
# 17. audio-to-tactile
#     言語: C
#     スター: 103
#
# 18. secrets-gradle-plugin
#     言語: Kotlin
#     スター: 1300
#
# 19. madi
#     言語: Python
#     スター: 78
#
# 20. google-api-javascript-client
#     言語: CSS
#     スター: 3400
#
# 21. btree
#     言語: Go
#     スター: 4100
#
# 22. it-cert-automation-practice
#     言語: Python
#     スター: 985
#
# 23. sxg-rs
#     言語: Rust
#     スター: 85
#
# 24. lyra
#     言語: C++
#     スター: 3900
#
# 25. schemarama
#     言語: JavaScript
#     スター: 146
#
# 26. premium-vs-standard-network-latency
#     言語: Shell
#     スター: 4
#
# 27. lut3d_utils
#     言語: Python
#     スター: 11
#
# 28. rust-derive-fuzztest
#     言語: Rust
#     スター: 18
#
# 29. real-time-intelligence-workshop
#     言語: Jupyter Notebook
#     スター: 27
#
# 30. ghost-kernel
#     言語: C
#     スター: 227
#
# ページ 33 完了: 30件取得 (累計: 990件)
# ----------------------------------------------------------------------
#
# Page 34:
# 1. ansicolor-dart
#     言語: Dart
#     スター: 104
#
# 2. libnop
#     言語: C++
#     スター: 576
#
# 3. zopfli
#     言語: C++
#     スター: 3600
#
# 4. flutter.widgets
#     言語: Dart
#     スター: 1400
#
# 5. lifetime_value
#     言語: Jupyter Notebook
#     スター: 365
#
# 6. ExoPlayer
#     言語: Java
#     スター: 22000
#
# 7. woff2
#     言語: C++
#     スター: 1700
#
# 8. pwlfit
#     言語: Jupyter Notebook
#     スター: 40
#
# 9. haloquest
#     言語: Jupyter Notebook
#     スター: 23
#
# ...
#     言語: Ruby
#     スター: 29
#
# 10. request-test
#     言語: Python
#     スター: 6
#
# 11. blockly-repo
#     言語: 不明
#     スター: 10
#
# 12. pindrop
#     言語: C++
#     スター: 142
#
# 13. goldfinch
#     言語: 不明
#     スター: 64
#
# 14. scene_lab
#     言語: C++
#     スター: 57
#
# 15. corgi
#     言語: C++
#     スター: 251
#
# 16. dropzone-polyfill
#     言語: HTML
#     スター: 5
#
# 17. ot-crdt-papers
#     言語: JavaScript
#     スター: 249
#
# 18. windowtester
#     言語: Java
#     スター: 19
#
# 19. fpc
#     言語: C
#     スター: 29
#
# 20. fchan-go
#     言語: Go
#     スター: 311
#
# 21. xdelta3-decoder-js
#     言語: C
#     スター: 13
#
# 22. appengine-phabricator
#     言語: Shell
#     スター: 19
#
# 23. cpp-frp
#     言語: C++
#     スター: 70
#
# 24. yang_vocoder
#     言語: MATLAB
#     スター: 91
#
# 25. keystone
#     言語: Elm
#     スター: 31
#
# 26. adapt-googleanalytics
#     言語: JavaScript
#     スター: 8
#
# 27. deepboost
#     言語: C++
#     スター: 154
#
# 28. mcic-coco
#     言語: 不明
#     スター: 24
#
# 29. readahead
#     言語: Go
#     スター: 136
#
# 30. source_transformer.dart
#     言語: Dart
#     スター: 9
#
# ページ 86 完了: 30件取得 (累計: 2580件)
# ----------------------------------------------------------------------
#
# Page 87:
# 1. mcafp
#     言語: Python
#     スター: 38
#
# 2. gtm-oauth
#     言語: Objective-C
#     スター: 24
#
# 3. morphie
#     言語: C++
#     スター: 23
#
# 4. libgep
#     言語: C++
#     スター: 55
#
# 5. smilesparser
#     言語: Python
#     スター: 13
#
# 6. built_json.dart
#     言語: 不明
#     スター: 19
#
# 7. conferenceDB
#     言語: HTML
#     スター: 9
#
# 8. indexable-pwa-samples
#     言語: JavaScript
#     スター: 56
#
# 9. enum_class.dart
#     言語: 不明
#     スター: 15
#
# 10. sass_generator
#     言語: 不明
#     スター: 4
#
# 11. vpn-reverse-tether
#     言語: C
#     スター: 190
#
# 12. protocall
#     言語: Python
#     スター: 13
#
# 13. transliteration
#     言語: 不明
#     スター: 56
#
# 14. power-traces
#     言語: Protocol Buffer
#     スター: 8
#
# 15. indexed-db-as-promised
#     言語: JavaScript
#     スター: 26
#
# 16. gotrace
#     言語: 不明
#     スター: 21
#
# 17. cameraraw
#     言語: Go
#     スター: 26
#
# 18. everythingisconnected
#     言語: JavaScript
#     スター: 19
#
# 19. libkml
#     言語: C++
#     スター: 97
#
# 20. geovelo
#     言語: JavaScript
#     スター: 44
#
# 21. gfw-toolkit
#     言語: Python
#     スター: 29
#
# 22. googleapps-message-recall
#     言語: Python
#     スター: 16
#
# 23. macops-MOMenu
#     言語: Objective-C
#     スター: 47
#
# 24. dart2java
#     言語: Java
#     スター: 61
#
# 25. param_runner
#     言語: Shell
#     スター: 4
#
# 26. gde-speakersbureau
#     言語: JavaScript
#     スター: 7
#
# 27. AppUpdateTrackerLib
#     言語: Java
#     スター: 7
#
# 28. rustcxx
#     言語: Rust
#     スター: 509
#
# 29. dualhttp
#     言語: JavaScript
#     スター: 22
#
# 30. go-webdav
#     言語: Go
#     スター: 70
#
# ページ 87 完了: 30件取得 (累計: 2610件)
# ----------------------------------------------------------------------
#
# Page 88:
# 1. dorusu-js
#     言語: JavaScript
#     スター: 40
#
# 2. identity-toolkit-go-client
#     言語: Go
#     スター: 57
#
# 3. dynamex-proto
#     言語: Protocol Buffer
#     スター: 7
#
# 4. auto-common
#     言語: 不明
#     スター: 5
#
# 5. auto-service
#     言語: 不明
#     スター: 5
#
# 6. auto-factory
#     言語: 不明
#     スター: 5
#
# 7. prudaq
#     言語: Eagle
#     スター: 123
#
# 8. realtime-help
#     言語: Python
#     スター: 20
#
# 9. pepper.js
#     言語: JavaScript
#     スター: 324
#
# 10. instant-hangouts
#     言語: JavaScript
#     スター: 184
#
# 11. LiquidFunPaint
#     言語: Java
#     スター: 166
#
# 12. easy-gwt-mock
#     言語: Java
#     スター: 13
#
# 13. gofountain
#     言語: Go
#     スター: 110
#
# 14. VoltAir
#     言語: C++
#     スター: 317
#
# 15. bzip2-rpc
#     言語: C
#     スター: 14
#
# 16. gipfeli
#     言語: C++
#     スター: 117
#
# 17. go-circuits
#     言語: Go
#     スター: 15
#
# 18. rpki-mgmt
#     言語: Puppet
#     スター: 6
#
# 19. simplecfg
#     言語: Java
#     スター: 11
#
# 20. maketrace
#     言語: C++
#     スター: 19
#
# 21. Chrome.Docs
#     言語: JavaScript
#     スター: 27
#
# 22. bluesky-watchface
#     言語: C
#     スター: 11
#
# 23. slowfs
#     言語: Go
#     スター: 58
#
# 24. arc-jazzy-linter
#     言語: PHP
#     スター: 18
#
# 25. merge_pyi
#     言語: Python
#     スター: 15
#
# 26. drone-firebase
#     言語: Go
#     スター: 14
#
# 27. cncmicroscope-cad
#     言語: OpenSCAD
#     スター: 15
#
# 28. access-bridge-explorer
#     言語: C#
#     スター: 126
#
# 29. gitwf
#     言語: 不明
#     スター: 4
#
# 30. arc-proselint
#     言語: PHP
#     スター: 17
#
# ページ 88 完了: 30件取得 (累計: 2640件)
# ----------------------------------------------------------------------
#
# Page 89:
# 1. channel-id-enclave
#     言語: 不明
#     スター: 33
#
# 2. generator-goro
#     言語: JavaScript
#     スター: 24
#
# 3. xpaf
#     言語: C++
#     スター: 153
#
# 4. google-empty-test-module
#     言語: 不明
#     スター: 3
#
# 5. cloud-reporting
#     言語: Java
#     スター: 8
#
# 6. reagera
#     言語: Java
#     スター: 13
#
# 7. py-decorators-tutorial
#     言語: Jupyter Notebook
#     スター: 31
#
# 8. identity-toolkit-node-client
#     言語: JavaScript
#     スター: 30
#
# 9. GOS-conventions
#     言語: Shell
#     スター: 8
#
# 10. identity-toolkit-java-client
#     言語: Java
#     スター: 37
#
# 11. jalic
#     言語: C
#     スター: 11
#
# 12. arc-regex-line-length-linter
#     言語: PHP
#     スター: 8
#
# 13. identity-toolkit-ruby-client
#     言語: Ruby
#     スター: 10
#
# 14. file-system-stress-testing
#     言語: C
#     スター: 104
#
# 15. linux-sensor
#     言語: C
#     スター: 32
#
# 16. multibox
#     言語: 不明
#     スター: 307
#
# 17. offline-content-packager
#     言語: 不明
#     スター: 35
#
# 18. crush-tools
#     言語: Shell
#     スター: 150
#
# 19. flutter-data
#     言語: Dart
#     スター: 11
#
# 20. resolver-library
#     言語: Python
#     スター: 7
#
# 21. hops
#     言語: C++
#     スター: 11
#
# 22. kythe-cloud9
#     言語: JavaScript
#     スター: 7
#
# 23. physical-web-core
#     言語: 不明
#     スター: 3
#
# 24. flooefi
#     言語: 不明
#     スター: 10
#
# 25. serialization.dart
#     言語: Dart
#     スター: 32
#
# 26. templatekit
#     言語: Objective-C
#     スター: 19
#
# 27. metrosvg
#     言語: C++
#     スター: 13
#
# 28. paramgmt
#     言語: Python
#     スター: 85
#
# 29. pienoon
#     言語: C++
#     スター: 438
#
# 30. translation-cards
#     言語: Java
#     スター: 17
#
# ページ 89 完了: 30件取得 (累計: 2670件)
# ----------------------------------------------------------------------
#
# Page 90:
# 1. topdown-btg-preordering
#     言語: C++
#     スター: 16
#
# 2. openpgp-interop
#     言語: 不明
#     スター: 8
#
# 3. appengine-codiad
#     言語: JavaScript
#     スター: 39
#
# 4. godata
#     言語: Go
#     スター: 26
#
# 5. opentest4j
#     言語: Java
#     スター: 5
#
# 6. identity-toolkit-php-client
#     言語: PHP
#     スター: 37
#
# 7. google-maven-parents
#     言語: 不明
#     スター: 6
#
# 8. identity-toolkit-python-client
#     言語: Python
#     スター: 32
#
# 9. Refaster
#     言語: Java
#     スター: 54
#
# 10. strabo
#     言語: Elixir
#     スター: 60
#
# 11. http2preload
#     言語: Go
#     スター: 20
#
# 12. checkers_classic
#     言語: Python
#     スター: 7
#
# 13. node-nest
#     言語: JavaScript
#     スター: 4
#
# 14. intellij-cmdline-vcs-plugin
#     言語: Java
#     スター: 4
#
# 15. docopt-scripts
#     言語: Go
#     スター: 6
#
# 16. xpra-upstart
#     言語: 不明
#     スター: 3
#
# 17. steamkeysactivator
#     言語: AppleScript
#     スター: 29
#
# 18. homebrew-xpra
#     言語: Ruby
#     スター: 9
#
# 19. shipshape-demo
#     言語: Python
#     スター: 4
#
# 20. hashing-demo
#     言語: C++
#     スター: 29
#
# 21. autopiper
#     言語: C++
#     スター: 48
#
# 22. inception
#     言語: 不明
#     スター: 877
#
# 23. clang-lens
#     言語: Haskell
#     スター: 20
#
# 24. crisis-info-hub
#     言語: JavaScript
#     スター: 35
#
# 25. dart-immutables
#     言語: Dart
#     スター: 6
#
# 26. streamhtmlparser
#     言語: C
#     スター: 17
#
# 27. pods-helper
#     言語: Objective-C
#     スター: 5
#
# 28. cluster-insight
#     言語: Python
#     スター: 99
#
# 29. freebase-wikidata-converter
#     言語: PHP
#     スター: 63
#
# 30. snappy-start
#     言語: C
#     スター: 450
#
# ページ 90 完了: 30件取得 (累計: 2700件)
# ----------------------------------------------------------------------
#
# Page 91:
# 1. capsicum-man-pages
#     言語: Groff
#     スター: 10
#
# 2. rust-multihash
#     言語: Rust
#     スター: 62
#
# 3. organ-donor-app
#     言語: 不明
#     スター: 3
#
# 4. trace-viewer
#     言語: 不明
#     スター: 491
#
# 5. rowhammer-test
#     言語: C++
#     スター: 984
#
# 6. ferret
#     言語: Java
#     スター: 8
#
# 7. module-server
#     言語: JavaScript
#     スター: 565
#
# 8. autoparse
#     言語: Ruby
#     スター: 146
#
# 9. android-studio-check
#     言語: Java
#     スター: 14
#
# 10. chromeos-filesystems
#     言語: JavaScript
#     スター: 125
#
# 11. gojiraw
#     言語: Go
#     スター: 16
#
# 12. terminal-py
#     言語: Python
#     スター: 7
#
# 13. lmctfy
#     言語: C++
#     スター: 3400
#
# 14. dart-shapeshift
#     言語: Dart
#     スター: 13
#
# 15. calenviroscreen
#     言語: R
#     スター: 8
#
# 16. cncmicroscope-code
#     言語: C++
#     スター: 24
#
# 17. o3dtoydefense
#     言語: JavaScript
#     スター: 8
#
# 18. epr
#     言語: JavaScript
#     スター: 16
#
# 19. codename-mvsv
#     言語: JavaScript
#     スター: 9
#
# 20. io-captions-gadget
#     言語: Python
#     スター: 5
#
# 21. ytstatistics-demo
#     言語: Java
#     スター: 5
#
# 22. sensei
#     言語: C++
#     スター: 55
#
# 23. comid
#     言語: Dart
#     スター: 15
#
# 24. service_worker.dart
#     言語: Dart
#     スター: 9
#
# 25. google-visualization-issues
#     言語: 不明
#     スター: 286
#
# 26. dart-doc_coverage
#     言語: Dart
#     スター: 7
#
# 27. voter-info-tool
#     言語: JavaScript
#     スター: 7
#
# 28. chrome-language-immersion
#     言語: JavaScript
#     スター: 46
#
# 29. coursebuilder_xblock_module
#     言語: Python
#     スター: 17
#
# 30. py-html-contextual-escaping
#     言語: Python
#     スター: 4
#
# ページ 91 完了: 30件取得 (累計: 2730件)
# ----------------------------------------------------------------------
#
# Page 92:
# 1. json-sans-eval
#     言語: HTML
#     スター: 7
#
# 2. mysql-tools
#     言語: Python
#     スター: 212
#
# 3. refr
#     言語: C++
#     スター: 28
#
# 4. coursebuilder-hello-world-module
#     言語: Python
#     スター: 8
#
# 5. dart-emacs-plugin-unsupported
#     言語: Emacs Lisp
#     スター: 12
#
# 6. older-mirrored-patches
#     言語: 不明
#     スター: 4
#
# 7. objectfilter
#     言語: Python
#     スター: 4
#
# 8. retrofit
#     言語: Java
#     スター: 43
#
# 9. nfc-smart-tag
#     言語: Java
#     スター: 12
#
# 10. irrduino
#     言語: Processing
#     スター: 51
#
# 11. reportlatency
#     言語: Perl
#     スター: 6
#
# 12. gmailsnooze
#     言語: JavaScript
#     スター: 16
#
# 13. deliberate
#     言語: 不明
#     スター: 4
#
# 14. network-visualizer-x
#     言語: 不明
#     スター: 5
#
# 15. reboot-somalia
#     言語: 不明
#     スター: 3
#
# 16. citizen-x
#     言語: 不明
#     スター: 5
#
# 17. pytypedecl
#     言語: Python
#     スター: 66
#
# 18. rysim
#     言語: Erlang
#     スター: 7
#
# 19. jsontoken-tmp
#     言語: 不明
#     スター: 3
#
# 20. go-shlex
#     言語: 不明
#     スター: 5
#
# 21. zarathustra
#     言語: Java
#     スター: 14
#
# 22. pull-request-mailer
#     言語: Haskell
#     スター: 45
#
# 23. elfling
#     言語: C++
#     スター: 25
#
# 24. vim-ft-vroom
#     言語: Vim Script
#     スター: 12
#
# 25. picview-for-android
#     言語: Java
#     スター: 51
#
# 26. picasa-app-demo
#     言語: Java
#     スター: 10
#
# 27. web-starter-kit-extras
#     言語: 不明
#     スター: 71
#
# 28. simple-pedometer
#     言語: Java
#     スター: 77
#
# 29. sensor-data-collection-library
#     言語: Java
#     スター: 46
#
# 30. ashier
#     言語: Python
#     スター: 29
#
# ページ 92 完了: 30件取得 (累計: 2760件)
# ----------------------------------------------------------------------
#
# Page 93:
# 1. coursebuilder-lti-module
#     言語: Python
#     スター: 16
#
# 2. episodes.dart
#     言語: Dart
#     スター: 14
#
# 3. polymer-dart-log-controller
#     言語: Dart
#     スター: 8
#
# 4. ebola-tools
#     言語: Python
#     スター: 15
#
# 5. pubsubhubbub
#     言語: 不明
#     スター: 6
#
# 6. dart-tagtree
#     言語: Dart
#     スター: 78
#
# 7. turing-doodle
#     言語: JavaScript
#     スター: 170
#
# 8. linear-book-scanner
#     言語: Python
#     スター: 81
#
# 9. java-thread-sanitizer
#     言語: Java
#     スター: 76
#
# 10. gin
#     言語: 不明
#     スター: 5
#
# 11. go-glicko2
#     言語: 不明
#     スター: 5
#
# 12. rct-automation
#     言語: C++
#     スター: 23
#
# 13. Idris-dev
#     言語: Haskell
#     スター: 9
#
# 14. forcefield
#     言語: Gosu
#     スター: 48
#
# 15. dart-gif-encoder
#     言語: Dart
#     スター: 28
#
# 16. glassbox
#     言語: R
#     スター: 22
#
# 17. coursebuilder-learning-analytics
#     言語: 不明
#     スター: 5
#
# 18. NLSdata
#     言語: R
#     スター: 8
#
# 19. jenkins-flaky-test-report
#     言語: 不明
#     スター: 5
#
# 20. build-debian-cloud
#     言語: Python
#     スター: 35
#
# 21. dart-collab
#     言語: Dart
#     スター: 47
#
# 22. wheelbarrow
#     言語: Python
#     スター: 11
#
# 23. photo-sphere
#     言語: 不明
#     スター: 4
#
# 24. oss-bench
#     言語: 不明
#     スター: 6
#
# 25. heartbleed-burp-extension
#     言語: Java
#     スター: 13
#
# 26. lab_device_proxy
#     言語: Python
#     スター: 39
#
# 27. gdal-autotest2
#     言語: 不明
#     スター: 4
#
# 28. patchfield
#     言語: Java
#     スター: 277
#
# 29. googleapps-password-generator
#     言語: 不明
#     スター: 27
#
# 30. YouCompleteSubl
#     言語: 不明
#     スター: 2
#
# ページ 93 完了: 30件取得 (累計: 2790件)
# ----------------------------------------------------------------------
#
# Page 94:
# 1. favcolor-findidp
#     言語: 不明
#     スター: 5
#
# 2. appengine_xblock_runtime
#     言語: Python
#     スター: 19
#
# 3. memcache-collections
#     言語: Python
#     スター: 66
#
# 4. course-builder
#     言語: 不明
#     スター: 5
#
# 5. favcolor-android
#     言語: Java
#     スター: 40
#
# 6. systemjs
#     言語: JavaScript
#     スター: 64
#
# 7. favcolor-ios
#     言語: 不明
#     スター: 5
#
# 8. pixelcycle-sample-app
#     言語: Dart
#     スター: 10
#
# 9. container-rfc
#     言語: 不明
#     スター: 11
#
# 10. gae-channel-api.dart
#     言語: Dart
#     スター: 10
#
# 11. ChannelPlate
#     言語: JavaScript
#     スター: 23
#
# 12. testRunner
#     言語: JavaScript
#     スター: 10
#
# 13. devtoolsExtended
#     言語: JavaScript
#     スター: 73
#
# 14. self-hosted-rss-to-email
#     言語: Go
#     スター: 29
#
# 15. zimu
#     言語: C
#     スター: 6
#
# 16. tsviewdb
#     言語: JavaScript
#     スター: 125
#
# 17. beta-binomial-fitting
#     言語: 不明
#     スター: 6
#
# 18. wiberg-minimization
#     言語: 不明
#     スター: 17
#
# 19. crx2app
#     言語: JavaScript
#     スター: 22
#
# 20. concatenate.js
#     言語: JavaScript
#     スター: 92
#
# 21. firmata.py
#     言語: Python
#     スター: 21
#
# 22. sirius
#     言語: 不明
#     スター: 8
#
# ページ 94 完了: 22件取得 (累計: 2812件)
# ----------------------------------------------------------------------
#
# 取得完了。 2812 個のリポジトリを取得しました
# 総ページ数: 94
#
# ステップ2: データベースに保存
# データベースに 2812 件保存しました
# データベース名: github_repositories.db
# テーブル名: repositories
#
# ステップ3: 保存したデータの確認
#
# 総レコード数: 2812件
#
# 【SELECT文実行】最初の20件:
# ----------------------------------------------------------------------
# ID    リポジトリ名                                   言語                    スター数
# ----------------------------------------------------------------------
# 1     device-infra                             Java                    58
# 2     nsjail                                   C++                  3,600
# 3     XNNPACK                                  C                    2,200
# 4     skia                                     C++                 10,000
# 5     budoux-extension                         TypeScript              16
# 6     nearby                                   C++                    887
# 7     qwix                                     Python                  64
# 8     aarch64-rt                               Rust                    17
# 9     percore                                  Rust                     8
# 10    wuffs                                    C                    4,700
# 11    magika                                   Python               9,800
# 12    jimfs                                    Java                 2,500
# 13    zerocopy                                 Rust                 2,100
# 14    skia-buildbot                            Go                     158
# 15    gtm-session-fetcher                      Objective-C            265
# 16    google-toolbox-for-mac                   Objective-C          1,200
# 17    ground-android                           Kotlin                 272
# 18    command-fds                              Rust                    42
# 19    yapf                                     Python              14,000
# 20    angle                                    C++                  3,800
#
# ======================================================================
# 「SELECT文実行」スター数トップ10:
# ----------------------------------------------------------------------
# 順位    リポジトリ名                                   言語                    スター数
# ----------------------------------------------------------------------
# 1     material-design-icons                    不明                  53,000
# 2     guava                                    Java                51,000
# 3     zx                                       JavaScript          45,000
# 4     styleguide                               HTML                39,000
# 5     googletest                               C++                 38,000
# 6     leveldb                                  C++                 38,000
# 7     comprehensive-rust                       Rust                32,000
# 8     material-design-lite                     HTML                32,000
# 9     python-fire                              Python              28,000
# 10    flatbuffers                              C++                 25,000
# 「SELECT文実行」言語別リポジトリ数:
# 言語                       リポジトリ数
# ----------------------------------------------------------------------
# Python                      584
# C++                         349
# Go                          290
# Java                        242
# JavaScript                  224
# 不明                          187
# TypeScript                  114
# C                           105
# Rust                         94
# Jupyter Notebook             87
# Dart                         86
# HTML                         70
# Shell                        60
# Kotlin                       47
# Objective-C                  34
# すべての処理が完了しました。
#
# 「データベースの確認」

# %%
# ステップ2: データベースに保存

if repositories:
    print("\nステップ2: データベースに保存")

    conn = sqlite3.connect('github_repositories.db')
    cursor = conn.cursor()

    # 既存のテーブルを削除して新規作成
    cursor.execute('DROP TABLE IF EXISTS repositories')

    # テーブル作成
    cursor.execute('''
    CREATE TABLE repositories (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        repository_name TEXT NOT NULL UNIQUE,
        main_language TEXT,
        star_count INTEGER,
        created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    )
    ''')

    # データ挿入
    cursor.executemany(
        'INSERT INTO repositories (repository_name, main_language, star_count) VALUES (?, ?, ?)',
        repositories
    )
    conn.commit()

    print(f"データベースに {len(repositories)} 件保存しました")
    print(f"データベース名: github_repositories.db")
    print(f"テーブル名: repositories")

   
    # ステップ3: 保存したデータをSELECT文で表示
    
    print("\nステップ3: 保存したデータの確認")
    

    # 全データ件数を確認
    cursor.execute('SELECT COUNT(*) FROM repositories')
    total_count = cursor.fetchone()[0]
    print(f"\n総レコード数: {total_count}件\n")

    # 最初の20件を表示
    print("【SELECT文実行】最初の20件:")
    print("-" * 70)
    cursor.execute('''
        SELECT id, repository_name, main_language, star_count
        FROM repositories
        ORDER BY id
        LIMIT 20
    ''')

    results = cursor.fetchall()
    print(f"{'ID':<5} {'リポジトリ名':<40} {'言語':<15} {'スター数':>10}")
    print("-" * 70)
    for row in results:
        print(f"{row[0]:<5} {row[1]:<40} {row[2]:<15} {row[3]:>10,}")

    # スター数トップ10
    print("\n" + "=" * 70)
    print("「SELECT文実行」スター数トップ10:")
    print("-" * 70)
    cursor.execute('''
        SELECT repository_name, main_language, star_count
        FROM repositories
        ORDER BY star_count DESC
        LIMIT 10
    ''')

    results = cursor.fetchall()
    print(f"{'順位':<5} {'リポジトリ名':<40} {'言語':<15} {'スター数':>10}")
    print("-" * 70)
    for i, row in enumerate(results, 1):
        print(f"{i:<5} {row[0]:<40} {row[1]:<15} {row[2]:>10,}")

    # 言語別集計
    print("「SELECT文実行」言語別リポジトリ数:")
    cursor.execute('''
        SELECT main_language, COUNT(*) as count
        FROM repositories
        GROUP BY main_language
        ORDER BY count DESC
        LIMIT 15
    ''')

    results = cursor.fetchall()
    print(f"{'言語':<20} {'リポジトリ数':>10}")
    print("-" * 70)
    for row in results:
        print(f"{row[0]:<20} {row[1]:>10}")

    conn.close()
    print("すべての処理が完了しました。")
else:
    print("\n取得したデータがありません。")
# Out:
# ステップ2: データベースに保存
# データベースに 2812 件保存しました
# データベース名: github_repositories.db
# テーブル名: repositories
#
# ステップ3: 保存したデータの確認
#
# 総レコード数: 2812件
#
# 【SELECT文実行】最初の20件:
# ----------------------------------------------------------------------
# ID    リポジトリ名                                   言語                    スター数
# ----------------------------------------------------------------------
# 1     device-infra                             Java                    58
# 2     nsjail                                   C++                  3,600
# 3     XNNPACK                                  C                    2,200
# 4     skia                                     C++                 10,000
# 5     budoux-extension                         TypeScript              16
# 6     nearby                                   C++                    887
# 7     qwix                                     Python                  64
# 8     aarch64-rt                               Rust                    17
# 9     percore                                  Rust                     8
# 10    wuffs                                    C                    4,700
# 11    magika                                   Python               9,800
# 12    jimfs                                    Java                 2,500
# 13    zerocopy                                 Rust                 2,100
# 14    skia-buildbot                            Go                     158
# 15    gtm-session-fetcher                      Objective-C            265
# 16    google-toolbox-for-mac                   Objective-C          1,200
# 17    ground-android                           Kotlin                 272
# 18    command-fds                              Rust                    42
# 19    yapf                                     Python              14,000
# 20    angle                                    C++                  3,800
#
# ======================================================================
# 「SELECT文実行」スター数トップ10:
# ----------------------------------------------------------------------
# 順位    リポジトリ名                                   言語                    スター数
# ----------------------------------------------------------------------
# 1     material-design-icons                    不明                  53,000
# 2     guava                                    Java                51,000
# 3     zx                                       JavaScript          45,000
# 4     styleguide                               HTML                39,000
# 5     googletest                               C++                 38,000
# 6     leveldb                                  C++                 38,000
# 7     comprehensive-rust                       Rust                32,000
# 8     material-design-lite                     HTML                32,000
# 9     python-fire                              Python              28,000
# 10    flatbuffers                              C++                 25,000
# 「SELECT文実行」言語別リポジトリ数:
# 言語                       リポジトリ数
# ----------------------------------------------------------------------
# Python                      584
# C++                         349
# Go                          290
# Java                        242
# JavaScript                  224
# 不明                          187
# TypeScript                  114
# C                           105
# Rust                         94
# Jupyter Notebook             87
# Dart                         86
# HTML                         70
# Shell                        60
# Kotlin                       47
# Objective-C                  34
# すべての処理が完了しました。
#
# 「データベースの確認」
